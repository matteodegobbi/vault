# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
sizeD = 8192
stringa = f"blackboxSize{sizeD},sizeTrainTest{sizeD}BETTERVERSION"


for epoch in range(1000,11000,1000):
  #print(epoch)
  try:
    #print(f"/home/fogliodicarta/Desktop/vault/programmiTesi/GAN_target/{stringa}/csv{epoch}.csv")
    arr=np.genfromtxt(f"/home/fogliodicarta/Desktop/vault/programmiTesi/SHADOW_GAN/{stringa}/csv{epoch}.csv",delimiter=',')
  except:
    print("error")
    continue
  plt.scatter(arr[0,:],arr[1,:]/arr[0,:],label=f"{epoch}")


plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.plot(arr[0,:],[0.5 for i in range (15)],"--",color='k')
plt.xlabel("top k")
plt.ylabel("percentage of correctly identified samples")
plt.savefig(f"BLACKBOXoriginal{sizeD},sizetrain{sizeD}.png",bbox_inches='tight')
plt.show()

# %%
arr[0,:]
# Out:
# array([   5.,   10.,   20.,   50.,  100.,  200.,  500., 1000., 1200.])
