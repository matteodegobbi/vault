# %% [markdown]
# # **Generative Adversarial Networks (GANs)**
# ### Lab Experience 3
#
#
# ---
#
#
# **GANs** are a form of neural network composed by 2 subnetworks:
# *   a *Generator* that is trained to produce data which is indiscernable from the true data,
# *   a *Discriminiator* that is trained to discern between the real and generated data.
#
# The overall network is trained with a **minimax loss function**:
#
# $ \min_{G} \max_{D} {V(D,G)}=\mathbb{E}_x[log(D(x))] + \mathbb{E}_z[log(1-D(G(z)))]$
#
# In this function:
#
# * $D(x)$ is the discriminator's estimate of the probability that real data instance $x$ is real.
# * $\mathbb{E}_x$ is the expected value over all real data instances.
# * $G(z)$ is the generator's output when given noise $z$.
# * $D(G(z))$ is the discriminator's estimate of the probability that a fake instance is real.
# * $\mathbb{E}_z$ is the expected value over all random inputs to the generator (in effect, the expected value over all generated fake instances $G(z)$).
#
# The formula derives from the cross-entropy between the real and generated distributions.
#
# The two subnetworks play a two players **minimax game** with value function $V(D, G)$, where:
# * the *Generator* tries to *maximize* the overall loss function,
# * the *Discriminator* tries to *minimize* the overall loss function.
#
# ![image.png](data:image/png;base64,...)
#
#
# ---
# #### References
# [1] I Goodfellow, J Pouget-Abadie, M Mirza, B Xu, D Warde-Farley, S Ozair, Y. Bengio. Advances in neural information processing systems, 2672-2680. https://arxiv.org/abs/1406.2661

# %% [markdown]
# ### Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, LeakyReLU, Reshape
from tensorflow.keras.layers import Conv2DTranspose, Conv2D, Dropout, Flatten
import time

from keras.utils import plot_model

from IPython import display

# %% [markdown]
# ### Load and prepare the dataset
#
# You will use the MNIST dataset to train the generator and the discriminator. The generator will generate handwritten digits resembling the MNIST data.
#
# Dataset **MNIST digits** contains 60,000 examples for training and 10,000 examples for testing.
# The digits are size-normalized and centered in a fixed-size image (28x28 pixels) with values from 0 to 255

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
DATASET_SIZE=15000
train_images=train_images[:DATASET_SIZE]
print(train_images.shape)
print(train_images.min(), train_images.max())
# Out:
# (15000, 28, 28)
# 0 255

# %%
plt.imshow(train_images[70])
train_images[1].shape
# Out:
# (28, 28)

# %%
#adding one channel as the last dimension to interface with TF layers
train_images = train_images.reshape(-1, 28, 28, 1).astype('float32')
#normalizing values in [-1, 1]
train_images = (train_images - 127.5) / 127.5

test_images = test_images.reshape(-1, 28, 28, 1).astype('float32')
#normalizing values in [-1, 1]
test_images = (test_images - 127.5) / 127.5

# %%
train_images.shape
# Out:
# (15000, 28, 28, 1)

# %%
BUFFER_SIZE = DATASET_SIZE
BATCH_SIZE = 256

# %%
# Batch and shuffle the data
train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# ## Create the models

# %% [markdown]
# ### The Generator
#
# The generator uses `tf.keras.layers.Conv2DTranspose` (upsampling) layers to produce an image from a seed (random noise). Start with a `Dense` layer that takes this seed as input, then upsample several times until you reach the desired image size of 28x28x1. Notice the `tf.keras.layers.LeakyReLU` activation for each layer, except the output layer which uses tanh.

# %%
def make_generator_model():
    model = tf.keras.Sequential(name='generator')
    model.add(
        Dense(
            7*7*256,
            use_bias=False,
            input_shape=(100,)
        )
    )
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Reshape((7, 7, 256)))

    model.add(
        Conv2DTranspose(
            filters=128,
            kernel_size=(5, 5),
            strides=(1, 1),
            padding='same',
            use_bias=False
        )
    )
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(
        Conv2DTranspose(
            filters=64,
            kernel_size=(5, 5),
            strides=(2, 2),
            padding='same',
            use_bias=False
        )
    )
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(
        Conv2DTranspose(
            filters=1,
            kernel_size=(5, 5),
            strides=(2, 2),
            padding='same',
            use_bias=False,
            activation='tanh'
        )
    )

    return model

# %% [markdown]
# # TODO 1
# Produce a noise vector of size `[1, 100]` and use the (as yet **untrained**) generator to create an image.

# %%
generator = make_generator_model()
generator.build()
generator.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12544)             1254400
#
#  batch_normalization (Batch  (None, 12544)             50176
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 12544)             0
#
#  reshape (Reshape)           (None, 7, 7, 256)         0
#
#  conv2d_transpose (Conv2DTr  (None, 7, 7, 128)         819200
#  anspose)
#
#  batch_normalization_1 (Bat  (None, 7, 7, 128)         512
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 7, 7, 128)         0
#
#  conv2d_transpose_1 (Conv2D  (None, 14, 14, 64)        204800
#  Transpose)
#
#  batch_normalization_2 (Bat  (None, 14, 14, 64)        256
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         1600
#  Transpose)
#
# =================================================================
# Total params: 2330944 (8.89 MB)
# Trainable params: 2305472 (8.79 MB)
# Non-trainable params: 25472 (99.50 KB)
# _________________________________________________________________

# %%
############################ CODE HERE ###############################
noise = tf.random.normal([1, 100])
generated_image = generator(noise, training=False)
############################ CODE HERE ###############################

plt.imshow(generated_image[0, :, :, 0], cmap='gray')

# %% [markdown]
# Visualize the model.

# %%
plot_model(generator, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### The Discriminator
#
# The is a CNN-based image classifier.

# %%
def make_discriminator_model():
    model = tf.keras.Sequential(name='discriminator')
    model.add(
        Conv2D(
            filters=64,
            kernel_size=(5, 5),
            strides=(2, 2),
            padding='same',
            input_shape=[28, 28, 1]
        )
    )
    model.add(LeakyReLU())
    model.add(Dropout(0.3))

    model.add(
        Conv2D(
            filters=128,
            kernel_size=(5, 5),
            strides=(2, 2),
            padding='same'
        )
    )
    model.add(LeakyReLU())
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(1, activation="sigmoid"))

    return model

# %% [markdown]
# # TODO 2
# Use the (yet **untrained**) discriminator to classify the generated images as real or fake. The model will be trained to output the probability that the image is real.

# %%
discriminator = make_discriminator_model()
discriminator.build()
discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 14, 64)        1664
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 128)         204928
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 128)         0
#
#  dropout_1 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense_1 (Dense)             (None, 1)                 6273
#
# =================================================================
# Total params: 212865 (831.50 KB)
# Trainable params: 212865 (831.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
############################ CODE HERE ###############################
decision = discriminator(generated_image, training=False)
############################ CODE HERE ###############################
print(decision)
# Out:
# tf.Tensor([[0.49989167]], shape=(1, 1), dtype=float32)

# %% [markdown]
# ## Define the loss and optimizers
#
# Define loss functions and optimizers for both models.

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy()

# %% [markdown]
# # TODO 3
# ### Discriminator loss
#
# This method quantifies how well the discriminator is able to distinguish real images from fakes. It compares the discriminator's predictions on real images to an array of 1s, and the discriminator's predictions on fake (generated) images to an array of 0s.
# The loss is of the form:
#
# $\frac{1}{m}\sum_{i=1}^{m}[\log D(\boldsymbol{x}^{(i)}) +\log(1-D(G(\boldsymbol{z}^{(i)})))]$

# %%
def discriminator_loss(real_output, fake_output):
    ############################ CODE HERE ###############################
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    ############################ CODE HERE ###############################
    return total_loss

# %% [markdown]
# # TODO 4
# ### Generator loss
# The generator's loss quantifies how well it was able to trick the discriminator. Intuitively, if the generator is performing well, the discriminator will classify the fake images as real (or 1). Here, compare the discriminators decisions on the generated images to an array of 1s.
# The generator loss is of the form:
#
# $\nabla_{\theta_g}\frac{1}{m}\sum_{i=1}^{m}\log(1-D(G(\boldsymbol{z}^{(i)})))$

# %%
def generator_loss(fake_output):
    ############################ CODE HERE ###############################
    gen_loss = cross_entropy(tf.ones_like(fake_output), fake_output)
    ############################ CODE HERE ###############################
    return gen_loss

# %% [markdown]
# The discriminator and the generator optimizers are different since you will train two networks separately.

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %% [markdown]
# ### Save checkpoints
# This notebook also demonstrates how to save and restore models, which can be helpful in case a long running training task is interrupted.

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %% [markdown]
# ## Define the training loop

# %%
EPOCHS = 450
noise_dim = 100
num_examples_to_generate = 16
seed = tf.random.normal([num_examples_to_generate, noise_dim])

# %% [markdown]
# # TODO 5
# The training loop begins with generator receiving a random seed as input. That seed is used to produce an image. The discriminator is then used to classify real images (drawn from the training set) and fakes images (produced by the generator). The loss is calculated for each of these models, and the gradients are used to update the generator and discriminator.

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images, generator_optimizer, discriminator_optimizer, noise_dim):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      ############################ CODE HERE ###############################
      generated_images = generator(noise, training=True)

      real_output = discriminator(images, training=True)
      fake_output = discriminator(generated_images, training=True)

      gen_loss = generator_loss(fake_output)
      disc_loss = discriminator_loss(real_output, fake_output)
      ############################ CODE HERE ###############################

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

# %%
def train(dataset, epochs, generator_optimizer, discriminator_optimizer, noise_dim):
  for epoch in range(epochs):

    '''if epoch % 150 == 0:
      checkpoint_dir = 'drive/MyDrive/checkpoints'
      checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
      checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)
      checkpoint.save(checkpoint_prefix+f"Epoch:{epoch}_{time.time()}")'''

    start = time.time()

    for image_batch in dataset:
      train_step(image_batch, generator_optimizer, discriminator_optimizer, noise_dim)

    # Produce images
    display.clear_output(wait=True)
    #generate_and_save_images(generator,epoch + 1,seed)

    print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))

  # Generate after the final epoch
  display.clear_output(wait=True)
  generate_and_save_images(generator,epochs,seed)

# %%
def generate_and_save_images(model, epoch, test_input):
  # Notice `training` is set to False.
  # This is so all layers run in inference mode (batchnorm).
  predictions = model(test_input, training=False)

  fig = plt.figure(figsize=(4, 4))

  for i in range(predictions.shape[0]):
      plt.subplot(4, 4, i+1)
      plt.imshow(predictions[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
      plt.axis('off')

  plt.savefig('generated_out/image_at_epoch_{:04d}.png'.format(epoch))
  plt.show()

# %% [markdown]
# # TODO 6
# ## Train the model
# Call the `train()` method defined above to train the generator and discriminator simultaneously  for `EPOCH` epochs. Note, training GANs can be tricky. It's important that the generator and discriminator do not overpower each other (e.g., that they train at a similar rate).
#
# At the beginning of the training, the generated images look like random noise. As training progresses, the generated digits will look increasingly real. After about 50 epochs, they resemble MNIST digits. This may take about one minute / epoch with the default settings on Colab.

# %%
############################ CODE HERE ###############################
#train(train_dataset, 150, generator_optimizer, discriminator_optimizer, noise_dim)
############################ CODE HERE ###############################

# %% [markdown]
# ## Automatic training of model in steps of 150 epochs to check for result overfitting on white box M.I.A.

# %%
epoch_total=0
for i in range(8):
  train(train_dataset, 150, generator_optimizer, discriminator_optimizer, noise_dim)
  epoch_total+=150
  ##################################################
  checkpoint_dir = 'drive/MyDrive/checkpoints2000'
  checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
  checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)
  checkpoint.save(checkpoint_prefix+f"Epoch:{epoch_total}_{time.time()}")
  ##############################################
  size_train_test=2000
  tensor_single=tf.convert_to_tensor(train_images[0:size_train_test])
  prob=discriminator(tensor_single)
  #print(prob.numpy().mean())
  labeled_prob_train=np.hstack((prob.numpy(),np.ones((size_train_test,1))))

  tensor_single=tf.convert_to_tensor(test_images[0:size_train_test])
  prob=discriminator(tensor_single)
  #print(prob.numpy().mean())
  labeled_prob_test=np.hstack((prob.numpy(),-1*np.ones((size_train_test,1))))

  labeled_probs = np.vstack((labeled_prob_train,labeled_prob_test))
  ##############################################
  fig,ax = plt.subplots()
  ax.set_title(f"likelihoods with {epoch_total} epochs and {60000} images in the training set")


  plt.hist(labeled_prob_train[:,0],color="tab:blue")

  plt.hist(labeled_prob_test[:,0],color="tab:orange")

  colors = {'training dataset':'tab:blue', 'test dataset':'tab:orange'}
  labels = list(colors.keys())
  handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
  plt.legend(handles, labels)
  plt.savefig(f"drive/MyDrive/csvs/likelihoods_epoch{epoch_total}_size{60000}.png")
  ##########################################################
  asd=labeled_probs[labeled_probs[:, 0].argsort()][::-1]
  asd[asd[:,1]==-1,1]=0
  top_k=[5,10,20,50,100,200,500,1000,1200]
  tp_out_of_top_k=list()
  for count,k in enumerate(top_k):
    tp_out_of_top_k.append(asd[0:k,1].sum())
  csv_topk=np.vstack((np.array(top_k,dtype=np.int32),np.array(tp_out_of_top_k,dtype=np.int32)))
  np.savetxt(f"drive/MyDrive/csvs/csv{epoch_total}.csv",csv_topk,delimiter=',')
# Out:
# Time for epoch 1 is 17.009166479110718 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-6d5fd85e142d> in <cell line: 2>()
#       1 epoch_total=0
#       2 for i in range(8):
# ----> 3   train(train_dataset, 150, generator_optimizer, discriminator_optimizer, noise_dim)
#       4   epoch_total+=150
#       5   ##################################################
#
# <ipython-input-99-4c1f4cc850e4> in train(dataset, epochs, generator_optimizer, discriminator_optimizer, noise_dim)
#      14
#      15     for image_batch in dataset:
# ---> 16       train_step(image_batch, generator_optimizer, discriminator_optimizer, noise_dim)
#      17
#      18     # Produce images
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     829
#     830       with OptionalXlaContext(self._jit_compile):
# --> 831         result = self._call(*args, **kwds)
#     832
#     833       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     865       # In this case we have created variables on the first call, so we run the
#     866       # defunned version which is guaranteed to never create variables.
# --> 867       return tracing_compilation.call_function(
#     868           args, kwds, self._no_variable_creation_config
#     869       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1262         and executing_eagerly):
#    1263       # No tape is watching; skip to running the function.
# -> 1264       return self._inference_function.flat_call(args)
#    1265     forward_backward = self._select_forward_and_backward_functions(
#    1266         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in flat_call(self, args)
#     215   def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216     """Calls with tensor inputs and returns the structured output."""
# --> 217     flat_outputs = self(*args)
#     218     return self.function_type.pack_output(flat_outputs)
#     219
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in __call__(self, *args)
#     250         with record.stop_recording():
#     251           if self._bound_context.executing_eagerly():
# --> 252             outputs = self._bound_context.call_function(
#     253                 self.name,
#     254                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1477     cancellation_context = cancellation.context()
#    1478     if cancellation_context is None:
# -> 1479       outputs = execute.execute(
#    1480           name.decode("utf-8"),
#    1481           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
n_generated_samples = 10000
noise_dim=100
new_seed = tf.random.normal([n_generated_samples, noise_dim])
generated_samples=generator(new_seed)

# %%
for i in range(n_generated_samples):
  plt.imshow(generated_samples[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
  plt.savefig('a/im{:06d}.png'.format(i))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-1bd4ceee8842> in <cell line: 1>()
#       1 for i in range(n_generated_samples):
#       2   plt.imshow(generated_samples[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
# ----> 3   plt.savefig('a/im{:06d}.png'.format(i))
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1022     fig = gcf()
#    1023     res = fig.savefig(*args, **kwargs)
# -> 1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#    1026
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080         if not self._is_idle_drawing:
#    2081             with self._idle_draw_cntx():
# -> 2082                 self.draw(*args, **kwargs)
#    2083
#    2084     @property
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     398              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399               else nullcontext()):
# --> 400             self.figure.draw(self.renderer)
#     401             # A GUI class may be need to update a window using this draw, so
#     402             # don't forget to call the superclass.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     639                 renderer.draw_image(gc, l, b, im, trans)
#     640         else:
# --> 641             im, l, b, trans = self.make_image(
#     642                 renderer, renderer.get_image_magnification())
#     643             if im is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     947         clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     948                 else self.figure.bbox)
# --> 949         return self._make_image(self._A, bbox, transformed_bbox, clip,
#     950                                 magnification, unsampled=unsampled)
#     951
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     494                 vrange += offset
#     495                 # resample the input data to the correct resolution and shape
# --> 496                 A_resampled = _resample(self, A_scaled, out_shape, t)
#     497                 del A_scaled  # Make sure we don't use A_scaled anymore!
#     498                 # Un-scale the resampled data to approximately the original
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     205     if resample is None:
#     206         resample = image_obj.get_resample()
# --> 207     _image.resample(data, out, transform,
#     208                     _interpd_[interpolation],
#     209                     resample,
#
# KeyboardInterrupt:

# %%
from PIL import Image
for i in range(n_generated_samples):
  im = Image.fromarray(generated_samples[i, :, :, 0].numpy() * 127.5 + 127.5)
  im=im.convert("L")
  im.save('a/im{:06d}.png'.format(i+10000))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
checkpoint.restore("/content/drive/MyDrive/checkpoints15000/450/ckptEpoch 50_1698696571.477729-1")

# %%
size_train_test=1200
images_training_set=15000
epoch_total=450

tensor_single=tf.convert_to_tensor(train_images[0:size_train_test])
prob=discriminator(tensor_single)
#print(prob.numpy().mean())
labeled_prob_train=np.hstack((prob.numpy(),np.ones((size_train_test,1))))

tensor_single=tf.convert_to_tensor(test_images[0:size_train_test])
prob=discriminator(tensor_single)
#print(prob.numpy().mean())
labeled_prob_test=np.hstack((prob.numpy(),-1*np.ones((size_train_test,1))))

labeled_probs = np.vstack((labeled_prob_train,labeled_prob_test))
##############################################
fig,ax = plt.subplots()
ax.set_title(f"likelihoods with {epoch_total} epochs and {images_training_set} images in the training set")


plt.hist(labeled_prob_train[:,0],color="tab:blue")

plt.hist(labeled_prob_test[:,0],color="tab:orange")

colors = {'training dataset':'tab:blue', 'test dataset':'tab:orange'}
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels)
plt.savefig(f"drive/MyDrive/csvs/likelihoods_epoch{epoch_total}_size{images_training_set}.png")
##########################################################
asd=labeled_probs[labeled_probs[:, 0].argsort()][::-1]
asd[asd[:,1]==-1,1]=0
top_k=[5,10,20,50,100,200,500,1000,1200]
tp_out_of_top_k=list()
for count,k in enumerate(top_k):
  tp_out_of_top_k.append(asd[0:k,1].sum())
csv_topk=np.vstack((np.array(top_k,dtype=np.int32),np.array(tp_out_of_top_k,dtype=np.int32)))
np.savetxt(f"drive/MyDrive/csvs/csv{epoch_total}.csv",csv_topk,delimiter=',')

# %%
def clean_outputs():
  folder = 'generated_outputs/'
  for filename in os.listdir(folder):
      file_path = os.path.join(folder, filename)
      try:
          if os.path.isfile(file_path) or os.path.islink(file_path):
              os.unlink(file_path)
          elif os.path.isdir(file_path):
              shutil.rmtree(file_path)
      except Exception as e:
          print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
discriminator.save_weights('./checkpoints/discriminatorMNIST50epochs')

# %%
# !zip -r size15000_epoch450.zip a
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   adding: a/im013335.png (stored 0%)
#   adding: a/im014129.png (stored 0%)
#   adding: a/im019169.png (stored 0%)
#   adding: a/im012278.png (stored 0%)
#   adding: a/im011627.png (stored 0%)
#   adding: a/im015495.png (stored 0%)
#   adding: a/im012677.png (stored 0%)
#   adding: a/im013817.png (stored 0%)
#   adding: a/im015386.png (stored 0%)
#   adding: a/im018429.png (stored 0%)
#   adding: a/im012976.png (stored 0%)
#   adding: a/im015424.png (stored 0%)
#   adding: a/im018250.png (stored 0%)
#   adding: a/im018897.png (stored 0%)
#   adding: a/im012636.png (stored 0%)
#   adding: a/im010835.png (stored 0%)
#   adding: a/im011697.png (stored 0%)
#   adding: a/im019857.png (stored 0%)
#   adding: a/im017495.png (stored 0%)
#   adding: a/im017803.png (stored 0%)
#   adding: a/im018632.png (stored 0%)
#   adding: a/im010833.png (stored 0%)
#   adding: a/im019845.png (stored 0%)
#   adding: a/im016953.png (stored 0%)
#   adding: a/im019779.png (stored 0%)
#   adding: a/im013085.png (stored 0%)
#   adding: a/im010587.png (stored 0%)
#   adding: a/im011905.png (stored 0%)
#   adding: a/im011136.png (stored 0%)
#   adding: a/im013244.png (stored 0%)
#   adding: a/im018921.png (stored 0%)
#   adding: a/im012798.png (stored 0%)
#   adding: a/im018686.png (stored 0%)
#   adding: a/im016520.png (stored 0%)
#   adding: a/im014969.png (stored 0%)
#   adding: a/im014365.png (stored 0%)
#   adding: a/im011938.png (stored 0%)
#   adding: a/im019365.png (stored 0%)
#   adding: a/im013020.png (stored 0%)
#   adding: a/im016835.png (stored 0%)
#   adding: a/im016228.png (stored 0%)
#   adding: a/im017817.png (stored 0%)
#   adding: a/im019943.png (stored 0%)
#   adding: a/im019599.png (stored 0%)
#   adding: a/im019309.png (stored 0%)
#   adding: a/im015313.png (stored 0%)
#   adding: a/im015805.png (stored 0%)
#   adding: a/im019852.png (stored 0%)
#   adding: a/im016665.png (stored 0%)
#   adding: a/im015309.png (stored 0%)
#   adding: a/im010239.png (stored 0%)
#   adding: a/im012660.png (stored 0%)
#   adding: a/im013841.png (stored 0%)
#   adding: a/im019677.png (stored 0%)
#   adding: a/im011952.png (stored 0%)
#   adding: a/im013513.png (stored 0%)
#   adding: a/im014358.png (stored 0%)
#   adding: a/im017052.png (stored 0%)
#   adding: a/im010975.png (stored 0%)
#   adding: a/im015969.png (stored 0%)
#   adding: a/im011524.png (stored 0%)
#   adding: a/im017945.png (stored 0%)
#   adding: a/im016382.png (stored 0%)
#   adding: a/im017604.png (stored 0%)
#   adding: a/im018154.png (stored 0%)
#   adding: a/im011145.png (stored 0%)
#   adding: a/im010303.png (stored 0%)
#   adding: a/im010090.png (stored 0%)
#   adding: a/im013170.png (stored 0%)
#   adding: a/im011830.png (stored 0%)
#   adding: a/im017683.png (stored 0%)
#   adding: a/im010606.png (stored 0%)
#   adding: a/im019977.png (stored 0%)
#   adding: a/im015184.png (stored 0%)
#   adding: a/im012850.png (stored 0%)
#   adding: a/im011403.png (stored 0%)
#   adding: a/im016886.png (stored 0%)
#   adding: a/im010734.png (stored 0%)
#   adding: a/im015467.png (stored 0%)
#   adding: a/im012276.png (stored 0%)
#   adding: a/im017237.png (stored 0%)
#   adding: a/im018833.png (stored 0%)
#   adding: a/im012151.png (stored 0%)
#   adding: a/im012568.png (stored 0%)
#   adding: a/im013012.png (stored 0%)
#   adding: a/im018758.png (stored 0%)
#   adding: a/im018292.png (stored 0%)
#   adding: a/im014278.png (stored 0%)
#   adding: a/im014394.png (stored 0%)
#   adding: a/im011516.png (stored 0%)
#   adding: a/im012110.png (stored 0%)
#   adding: a/im012714.png (stored 0%)
#   adding: a/im011454.png (stored 0%)
#   adding: a/im019735.png (stored 0%)
#   adding: a/im019266.png (stored 0%)
#   adding: a/im015393.png (stored 0%)
#   adding: a/im010657.png (stored 0%)
#   adding: a/im017493.png (stored 0%)
#   adding: a/im014202.png (stored 0%)
#   adding: a/im011908.png (stored 0%)
#   adding: a/im018249.png (stored 0%)
#   adding: a/im015689.png (stored 0%)
#   adding: a/im014602.png (stored 0%)
#   adding: a/im016334.png (stored 0%)
#   adding: a/im015423.png (stored 0%)
#   adding: a/im011283.png (stored 0%)
#   adding: a/im018597.png (stored 0%)
#   adding: a/im013304.png (stored 0%)
#   adding: a/im017252.png (stored 0%)
#   adding: a/im011192.png (stored 0%)
#   adding: a/im010414.png (stored 0%)
#   adding: a/im018697.png (stored 0%)
#   adding: a/im013826.png (stored 0%)
#   adding: a/im019608.png (stored 0%)
#   adding: a/im011434.png (stored 0%)
#   adding: a/im018606.png (stored 0%)
#   adding: a/im019102.png (stored 0%)
#   adding: a/im016560.png (stored 0%)
#   adding: a/im015998.png (stored 0%)
#   adding: a/im014414.png (stored 0%)
#   adding: a/im015613.png (stored 0%)
#   adding: a/im014643.png (stored 0%)
#   adding: a/im010441.png (stored 0%)
#   adding: a/im011600.png (stored 0%)
#   adding: a/im019193.png (stored 0%)
#   adding: a/im015395.png (stored 0%)
#   adding: a/im014085.png (stored 0%)
#   adding: a/im017786.png (stored 0%)
#   adding: a/im018662.png (stored 0%)
#   adding: a/im011882.png (stored 0%)
#   adding: a/im014294.png (stored 0%)
#   adding: a/im018379.png (stored 0%)
#   adding: a/im017875.png (stored 0%)
#   adding: a/im010986.png (stored 0%)
#   adding: a/im011344.png (stored 0%)
#   adding: a/im012731.png (stored 0%)
#   adding: a/im015346.png (stored 0%)
#   adding: a/im014760.png (stored 0%)
#   adding: a/im010444.png (stored 0%)
#   adding: a/im016710.png (stored 0%)
#   adding: a/im010457.png (stored 0%)
#   adding: a/im019369.png (stored 0%)
#   adding: a/im019122.png (stored 0%)
#   adding: a/im010314.png (stored 0%)
#   adding: a/im012543.png (stored 0%)
#   adding: a/im015592.png (stored 0%)
#   adding: a/im014957.png (stored 0%)
#   adding: a/im017187.png (stored 0%)
#   adding: a/im013569.png (stored 0%)
#   adding: a/im013686.png (stored 0%)
#   adding: a/im019616.png (stored 0%)
#   adding: a/im019067.png (stored 0%)
#   adding: a/im011847.png (stored 0%)
#   adding: a/im012450.png (stored 0%)
#   adding: a/im012094.png (stored 0%)
#   adding: a/im013298.png (stored 0%)
#   adding: a/im017766.png (stored 0%)
#   adding: a/im010195.png (stored 0%)
#   adding: a/im014418.png (stored 0%)
#   adding: a/im016468.png (stored 0%)
#   adding: a/im011010.png (stored 0%)
#   adding: a/im019875.png (stored 0%)
#   adding: a/im017092.png (stored 0%)
#   adding: a/im018585.png (stored 0%)
#   adding: a/im013646.png (stored 0%)
#   adding: a/im014698.png (stored 0%)
#   adding: a/im011813.png (stored 0%)
#   adding: a/im011681.png (stored 0%)
#   adding: a/im018123.png (stored 0%)
#   adding: a/im018856.png (stored 0%)
#   adding: a/im015114.png (stored 0%)
#   adding: a/im013860.png (stored 0%)
#   adding: a/im016246.png (stored 0%)
#   adding: a/im014586.png (stored 0%)
#   adding: a/im017543.png (stored 0%)
#   adding: a/im014529.png (stored 0%)
#   adding: a/im010033.png (stored 0%)
#   adding: a/im013238.png (stored 0%)
#   adding: a/im012515.png (stored 0%)
#   adding: a/im013604.png (stored 0%)
#   adding: a/im017195.png (stored 0%)
#   adding: a/im013805.png (stored 0%)
#   adding: a/im016205.png (stored 0%)
#   adding: a/im015864.png (stored 0%)
#   adding: a/im013185.png (stored 0%)
#   adding: a/im017783.png (stored 0%)
#   adding: a/im010931.png (stored 0%)
#   adding: a/im010790.png (stored 0%)
#   adding: a/im016239.png (stored 0%)
#   adding: a/im011907.png (stored 0%)
#   adding: a/im017394.png (stored 0%)
#   adding: a/im014919.png (stored 0%)
#   adding: a/im014171.png (stored 0%)
#   adding: a/im017407.png (stored 0%)
#   adding: a/im018140.png (stored 0%)
#   adding: a/im011991.png (stored 0%)
#   adding: a/im015319.png (stored 0%)
#   adding: a/im012074.png (stored 0%)
#   adding: a/im013063.png (stored 0%)
#   adding: a/im016785.png (stored 0%)
#   adding: a/im012779.png (stored 0%)
#   adding: a/im015735.png (stored 0%)
#   adding: a/im019740.png (stored 0%)
#   adding: a/im017012.png (stored 0%)
#   adding: a/im014150.png (stored 0%)
#   adding: a/im014005.png (stored 0%)
#   adding: a/im011845.png (stored 0%)
#   adding: a/im014901.png (stored 0%)
#   adding: a/im017269.png (stored 0%)
#   adding: a/im010482.png (stored 0%)
#   adding: a/im012654.png (stored 0%)
#   adding: a/im012761.png (stored 0%)
#   adding: a/im016314.png (stored 0%)
#   adding: a/im016695.png (stored 0%)
#   adding: a/im012484.png (stored 0%)
#   adding: a/im017836.png (stored 0%)
#   adding: a/im011589.png (stored 0%)
#   adding: a/im016659.png (stored 0%)
#   adding: a/im014905.png (stored 0%)
#   adding: a/im017369.png (stored 0%)
#   adding: a/im010181.png (stored 0%)
#   adding: a/im016798.png (stored 0%)
#   adding: a/im015895.png (stored 0%)
#   adding: a/im013676.png (stored 0%)
#   adding: a/im011747.png (stored 0%)
#   adding: a/im018831.png (stored 0%)
#   adding: a/im012826.png (stored 0%)
#   adding: a/im019316.png (stored 0%)
#   adding: a/im018966.png (stored 0%)
#   adding: a/im017018.png (stored 0%)
#   adding: a/im014795.png (stored 0%)
#   adding: a/im015371.png (stored 0%)
#   adding: a/im011667.png (stored 0%)
#   adding: a/im017373.png (stored 0%)
#   adding: a/im018462.png (stored 0%)
#   adding: a/im017458.png (stored 0%)
#   adding: a/im015033.png (stored 0%)
#   adding: a/im019769.png (stored 0%)
#   adding: a/im013963.png (stored 0%)
#   adding: a/im014968.png (stored 0%)
#   adding: a/im018352.png (stored 0%)
#   adding: a/im014056.png (stored 0%)
#   adding: a/im016441.png (stored 0%)
#   adding: a/im012022.png (stored 0%)
#   adding: a/im013402.png (stored 0%)
#   adding: a/im012747.png (stored 0%)
#   adding: a/im018230.png (stored 0%)
#   adding: a/im017587.png (stored 0%)
#   adding: a/im016495.png (stored 0%)
#   adding: a/im012712.png (stored 0%)
#   adding: a/im010526.png (stored 0%)
#   adding: a/im017196.png (stored 0%)
#   adding: a/im016857.png (stored 0%)
#   adding: a/im015623.png (stored 0%)
#   adding: a/im019268.png (stored 0%)
#   adding: a/im010143.png (stored 0%)
#   adding: a/im014419.png (stored 0%)
#   adding: a/im019760.png (stored 0%)
#   adding: a/im016337.png (stored 0%)
#   adding: a/im017904.png (stored 0%)
#   adding: a/im013174.png (stored 0%)
#   adding: a/im016180.png (stored 0%)
#   adding: a/im016498.png (stored 0%)
#   adding: a/im010329.png (stored 0%)
#   adding: a/im019325.png (stored 0%)
#   adding: a/im017919.png (stored 0%)
#   adding: a/im015583.png (stored 0%)
#   adding: a/im013904.png (stored 0%)
#   adding: a/im018534.png (stored 0%)
#   adding: a/im010670.png (stored 0%)
#   adding: a/im011006.png (stored 0%)
#   adding: a/im012743.png (stored 0%)
#   adding: a/im017391.png (stored 0%)
#   adding: a/im014872.png (stored 0%)
#   adding: a/im015745.png (stored 0%)
#   adding: a/im012081.png (stored 0%)
#   adding: a/im015023.png (stored 0%)
#   adding: a/im015653.png (stored 0%)
#   adding: a/im019675.png (stored 0%)
#   adding: a/im011903.png (stored 0%)
#   adding: a/im018495.png (stored 0%)
#   adding: a/im014446.png (stored 0%)
#   adding: a/im011535.png (stored 0%)
#   adding: a/im012039.png (stored 0%)
#   adding: a/im014916.png (stored 0%)
#   adding: a/im010579.png (stored 0%)
#   adding: a/im010016.png (stored 0%)
#   adding: a/im019500.png (stored 0%)
#   adding: a/im017108.png (stored 0%)
#   adding: a/im011077.png (stored 0%)
#   adding: a/im011881.png (stored 0%)
#   adding: a/im017035.png (stored 0%)
#   adding: a/im013056.png (stored 0%)
#   adding: a/im013295.png (stored 0%)
#   adding: a/im013610.png (stored 0%)
#   adding: a/im013704.png (stored 0%)
#   adding: a/im011321.png (stored 0%)
#   adding: a/im017674.png (stored 0%)
#   adding: a/im018658.png (stored 0%)
#   adding: a/im019583.png (stored 0%)
#   adding: a/im017539.png (stored 0%)
#   adding: a/im011153.png (stored 0%)
#   adding: a/im017578.png (stored 0%)
#   adding: a/im014303.png (stored 0%)
#   adding: a/im018728.png (stored 0%)
#   adding: a/im012289.png (stored 0%)
#   adding: a/im013131.png (stored 0%)
#   adding: a/im016186.png (stored 0%)
#   adding: a/im017489.png (stored 0%)
#   adding: a/im015435.png (stored 0%)
#   adding: a/im015723.png (stored 0%)
#   adding: a/im015666.png (stored 0%)
#   adding: a/im015560.png (stored 0%)
#   adding: a/im015990.png (stored 0%)
#   adding: a/im014993.png (stored 0%)
#   adding: a/im014593.png (stored 0%)
#   adding: a/im018078.png (stored 0%)
#   adding: a/im010837.png (stored 0%)
#   adding: a/im017232.png (stored 0%)
#   adding: a/im014762.png (stored 0%)
#   adding: a/im012635.png (stored 0%)
#   adding: a/im015844.png (stored 0%)
#   adding: a/im011289.png (stored 0%)
#   adding: a/im018730.png (stored 0%)
#   adding: a/im017813.png (stored 0%)
#   adding: a/im012196.png (stored 0%)
#   adding: a/im014368.png (stored 0%)
#   adding: a/im016488.png (stored 0%)
#   adding: a/im016958.png (stored 0%)
#   adding: a/im015668.png (stored 0%)
#   adding: a/im010954.png (stored 0%)
#   adding: a/im014785.png (stored 0%)
#   adding: a/im018112.png (stored 0%)
#   adding: a/im016037.png (stored 0%)
#   adding: a/im013629.png (stored 0%)
#   adding: a/im016580.png (stored 0%)
#   adding: a/im014120.png (stored 0%)
#   adding: a/im018628.png (stored 0%)
#   adding: a/im011757.png (stored 0%)
#   adding: a/im016440.png (stored 0%)
#   adding: a/im012869.png (stored 0%)
#   adding: a/im017774.png (stored 0%)
#   adding: a/im011019.png (stored 0%)
#   adding: a/im015636.png (stored 0%)
#   adding: a/im010610.png (stored 0%)
#   adding: a/im010567.png (stored 0%)
#   adding: a/im017564.png (stored 0%)
#   adding: a/im014706.png (stored 0%)
#   adding: a/im018132.png (stored 0%)
#   adding: a/im017395.png (stored 0%)
#   adding: a/im016281.png (stored 0%)
#   adding: a/im017859.png (stored 0%)
#   adding: a/im016932.png (stored 0%)
#   adding: a/im018888.png (stored 0%)
#   adding: a/im011247.png (stored 0%)
#   adding: a/im018117.png (stored 0%)
#   adding: a/im015657.png (stored 0%)
#   adding: a/im017110.png (stored 0%)
#   adding: a/im012140.png (stored 0%)
#   adding: a/im012773.png (stored 0%)
#   adding: a/im019881.png (stored 0%)
#   adding: a/im014983.png (stored 0%)
#   adding: a/im013463.png (stored 0%)
#   adding: a/im016527.png (stored 0%)
#   adding: a/im019351.png (stored 0%)
#   adding: a/im019233.png (stored 0%)
#   adding: a/im015333.png (stored 0%)
#   adding: a/im018359.png (stored 0%)
#   adding: a/im011918.png (stored 0%)
#   adding: a/im014025.png (stored 0%)
#   adding: a/im019158.png (stored 0%)
#   adding: a/im014749.png (stored 0%)
#   adding: a/im012200.png (stored 0%)
#   adding: a/im017580.png (stored 0%)
#   adding: a/im014442.png (stored 0%)
#   adding: a/im017207.png (stored 0%)
#   adding: a/im011936.png (stored 0%)
#   adding: a/im016142.png (stored 0%)
#   adding: a/im019376.png (stored 0%)
#   adding: a/im011442.png (stored 0%)
#   adding: a/im016293.png (stored 0%)
#   adding: a/im013927.png (stored 0%)
#   adding: a/im012066.png (stored 0%)
#   adding: a/im010353.png (stored 0%)
#   adding: a/im018254.png (stored 0%)
#   adding: a/im010663.png (stored 0%)
#   adding: a/im010020.png (stored 0%)
#   adding: a/im017749.png (stored 0%)
#   adding: a/im016989.png (stored 0%)
#   adding: a/im012071.png (stored 0%)
#   adding: a/im013833.png (stored 0%)
#   adding: a/im019013.png (stored 0%)
#   adding: a/im010922.png (stored 0%)
#   adding: a/im019265.png (stored 0%)
#   adding: a/im010549.png (stored 0%)
#   adding: a/im012967.png (stored 0%)
#   adding: a/im013094.png (stored 0%)
#   adding: a/im016265.png (stored 0%)
#   adding: a/im017492.png (stored 0%)
#   adding: a/im019337.png (stored 0%)
#   adding: a/im013715.png (stored 0%)
#   adding: a/im012100.png (stored 0%)
#   adding: a/im010673.png (stored 0%)
#   adding: a/im018992.png (stored 0%)
#   adding: a/im019513.png (stored 0%)
#   adding: a/im011871.png (stored 0%)
#   adding: a/im018377.png (stored 0%)
#   adding: a/im012438.png (stored 0%)
#   adding: a/im011754.png (stored 0%)
#   adding: a/im015279.png (stored 0%)
#   adding: a/im014841.png (stored 0%)
#   adding: a/im010988.png (stored 0%)
#   adding: a/im019131.png (stored 0%)
#   adding: a/im011710.png (stored 0%)
#   adding: a/im019254.png (stored 0%)
#   adding: a/im015035.png (stored 0%)
#   adding: a/im011708.png (stored 0%)
#   adding: a/im014746.png (stored 0%)
#   adding: a/im018550.png (stored 0%)
#   adding: a/im015526.png (stored 0%)
#   adding: a/im015383.png (stored 0%)
#   adding: a/im015352.png (stored 0%)
#   adding: a/im019039.png (stored 0%)
#   adding: a/im011250.png (stored 0%)
#   adding: a/im016277.png (stored 0%)
#   adding: a/im015146.png (stored 0%)
#   adding: a/im014959.png (stored 0%)
#   adding: a/im011746.png (stored 0%)
#   adding: a/im010234.png (stored 0%)
#   adding: a/im018817.png (stored 0%)
#   adding: a/im012887.png (stored 0%)
#   adding: a/im011070.png (stored 0%)
#   adding: a/im019786.png (stored 0%)
#   adding: a/im019832.png (stored 0%)
#   adding: a/im018011.png (stored 0%)
#   adding: a/im019312.png (stored 0%)
#   adding: a/im011090.png (stored 0%)
#   adding: a/im017520.png (stored 0%)
#   adding: a/im018411.png (stored 0%)
#   adding: a/im010187.png (stored 0%)
#   adding: a/im011369.png (stored 0%)
#   adding: a/im016176.png (stored 0%)
#   adding: a/im010182.png (stored 0%)
#   adding: a/im013950.png (stored 0%)
#   adding: a/im015685.png (stored 0%)
#   adding: a/im018398.png (stored 0%)
#   adding: a/im018103.png (stored 0%)
#   adding: a/im016929.png (stored 0%)
#   adding: a/im018445.png (stored 0%)
#   adding: a/im019803.png (stored 0%)
#   adding: a/im012361.png (stored 0%)
#   adding: a/im014272.png (stored 0%)
#   adding: a/im010092.png (stored 0%)
#   adding: a/im019626.png (stored 0%)
#   adding: a/im018621.png (stored 0%)
#   adding: a/im017546.png (stored 0%)
#   adding: a/im018247.png (stored 0%)
#   adding: a/im018374.png (stored 0%)
#   adding: a/im010471.png (stored 0%)
#   adding: a/im010878.png (stored 0%)
#   adding: a/im011989.png (stored 0%)
#   adding: a/im011095.png (stored 0%)
#   adding: a/im017013.png (stored 0%)
#   adding: a/im015016.png (stored 0%)
#   adding: a/im010293.png (stored 0%)
#   adding: a/im019009.png (stored 0%)
#   adding: a/im019183.png (stored 0%)
#   adding: a/im011421.png (stored 0%)
#   adding: a/im015561.png (stored 0%)
#   adding: a/im012338.png (stored 0%)
#   adding: a/im019247.png (stored 0%)
#   adding: a/im014686.png (stored 0%)
#   adding: a/im013377.png (stored 0%)
#   adding: a/im011821.png (stored 0%)
#   adding: a/im014997.png (stored 0%)
#   adding: a/im017781.png (stored 0%)
#   adding: a/im012337.png (stored 0%)
#   adding: a/im015132.png (stored 0%)
#   adding: a/im018795.png (stored 0%)
#   adding: a/im019831.png (stored 0%)
#   adding: a/im019178.png (stored 0%)
#   adding: a/im018332.png (stored 0%)
#   adding: a/im014553.png (stored 0%)
#   adding: a/im010543.png (stored 0%)
#   adding: a/im011621.png (stored 0%)
#   adding: a/im016213.png (stored 0%)
#   adding: a/im010873.png (stored 0%)
#   adding: a/im010483.png (stored 0%)
#   adding: a/im015347.png (stored 0%)
#   adding: a/im014137.png (stored 0%)
#   adding: a/im011188.png (stored 0%)
#   adding: a/im010445.png (stored 0%)
#   adding: a/im011643.png (stored 0%)
#   adding: a/im010298.png (stored 0%)
#   adding: a/im016711.png (stored 0%)
#   adding: a/im019821.png (stored 0%)
#   adding: a/im017649.png (stored 0%)
#   adding: a/im010681.png (stored 0%)
#   adding: a/im016294.png (stored 0%)
#   adding: a/im014926.png (stored 0%)
#   adding: a/im012078.png (stored 0%)
#   adding: a/im017218.png (stored 0%)
#   adding: a/im013575.png (stored 0%)
#   adding: a/im013443.png (stored 0%)
#   adding: a/im018599.png (stored 0%)
#   adding: a/im016374.png (stored 0%)
#   adding: a/im014451.png (stored 0%)
#   adding: a/im016911.png (stored 0%)
#   adding: a/im016887.png (stored 0%)
#   adding: a/im013033.png (stored 0%)
#   adding: a/im014256.png (stored 0%)
#   adding: a/im018678.png (stored 0%)
#   adding: a/im012414.png (stored 0%)
#   adding: a/im017918.png (stored 0%)
#   adding: a/im018018.png (stored 0%)
#   adding: a/im018557.png (stored 0%)
#   adding: a/im014441.png (stored 0%)
#   adding: a/im015630.png (stored 0%)
#   adding: a/im017455.png (stored 0%)
#   adding: a/im016511.png (stored 0%)
#   adding: a/im015248.png (stored 0%)
#   adding: a/im019915.png (stored 0%)
#   adding: a/im010236.png (stored 0%)
#   adding: a/im016991.png (stored 0%)
#   adding: a/im014306.png (stored 0%)
#   adding: a/im017370.png (stored 0%)
#   adding: a/im011339.png (stored 0%)
#   adding: a/im017438.png (stored 0%)
#   adding: a/im011186.png (stored 0%)
#   adding: a/im019527.png (stored 0%)
#   adding: a/im017297.png (stored 0%)
#   adding: a/im016329.png (stored 0%)
#   adding: a/im010183.png (stored 0%)
#   adding: a/im016924.png (stored 0%)
#   adding: a/im011441.png (stored 0%)
#   adding: a/im011755.png (stored 0%)
#   adding: a/im013548.png (stored 0%)
#   adding: a/im017150.png (stored 0%)
#   adding: a/im012305.png (stored 0%)
#   adding: a/im016964.png (stored 0%)
#   adding: a/im018696.png (stored 0%)
#   adding: a/im014400.png (stored 0%)
#   adding: a/im011399.png (stored 0%)
#   adding: a/im016779.png (stored 0%)
#   adding: a/im014908.png (stored 0%)
#   adding: a/im017496.png (stored 0%)
#   adding: a/im016172.png (stored 0%)
#   adding: a/im014122.png (stored 0%)
#   adding: a/im019969.png (stored 0%)
#   adding: a/im019255.png (stored 0%)
#   adding: a/im019378.png (stored 0%)
#   adding: a/im011570.png (stored 0%)
#   adding: a/im018735.png (stored 0%)
#   adding: a/im019948.png (stored 0%)
#   adding: a/im012349.png (stored 0%)
#   adding: a/im011278.png (stored 0%)
#   adding: a/im016413.png (stored 0%)
#   adding: a/im010649.png (stored 0%)
#   adding: a/im013266.png (stored 0%)
#   adding: a/im018268.png (stored 0%)
#   adding: a/im012534.png (stored 0%)
#   adding: a/im011029.png (stored 0%)
#   adding: a/im018160.png (stored 0%)
#   adding: a/im015049.png (stored 0%)
#   adding: a/im018084.png (stored 0%)
#   adding: a/im019541.png (stored 0%)
#   adding: a/im012637.png (stored 0%)
#   adding: a/im012136.png (stored 0%)
#   adding: a/im017642.png (stored 0%)
#   adding: a/im012061.png (stored 0%)
#   adding: a/im011671.png (stored 0%)
#   adding: a/im011207.png (stored 0%)
#   adding: a/im013750.png (stored 0%)
#   adding: a/im016202.png (stored 0%)
#   adding: a/im016596.png (stored 0%)
#   adding: a/im013055.png (stored 0%)
#   adding: a/im015234.png (stored 0%)
#   adding: a/im014326.png (stored 0%)
#   adding: a/im014075.png (stored 0%)
#   adding: a/im012830.png (stored 0%)
#   adding: a/im014813.png (stored 0%)
#   adding: a/im017990.png (stored 0%)
#   adding: a/im016109.png (stored 0%)
#   adding: a/im012639.png (stored 0%)
#   adding: a/im013810.png (stored 0%)
#   adding: a/im017844.png (stored 0%)
#   adding: a/im018540.png (stored 0%)
#   adding: a/im011158.png (stored 0%)
#   adding: a/im014280.png (stored 0%)
#   adding: a/im012302.png (stored 0%)
#   adding: a/im018702.png (stored 0%)
#   adding: a/im016339.png (stored 0%)
#   adding: a/im014522.png (stored 0%)
#   adding: a/im012685.png (stored 0%)
#   adding: a/im016312.png (stored 0%)
#   adding: a/im013454.png (stored 0%)
#   adding: a/im017345.png (stored 0%)
#   adding: a/im018533.png (stored 0%)
#   adding: a/im010335.png (stored 0%)
#   adding: a/im015037.png (stored 0%)
#   adding: a/im019151.png (stored 0%)
#   adding: a/im017756.png (stored 0%)
#   adding: a/im014956.png (stored 0%)
#   adding: a/im014134.png (stored 0%)
#   adding: a/im019847.png (stored 0%)
#   adding: a/im011107.png (stored 0%)
#   adding: a/im012778.png (stored 0%)
#   adding: a/im010615.png (stored 0%)
#   adding: a/im015520.png (stored 0%)
#   adding: a/im012397.png (stored 0%)
#   adding: a/im016772.png (stored 0%)
#   adding: a/im016111.png (stored 0%)
#   adding: a/im017765.png (stored 0%)
#   adding: a/im011105.png (stored 0%)
#   adding: a/im019906.png (stored 0%)
#   adding: a/im014637.png (stored 0%)
#   adding: a/im013978.png (stored 0%)
#   adding: a/im016309.png (stored 0%)
#   adding: a/im012424.png (stored 0%)
#   adding: a/im015573.png (stored 0%)
#   adding: a/im014915.png (stored 0%)
#   adding: a/im011563.png (stored 0%)
#   adding: a/im015361.png (stored 0%)
#   adding: a/im014711.png (stored 0%)
#   adding: a/im011613.png (stored 0%)
#   adding: a/im014867.png (stored 0%)
#   adding: a/im017334.png (stored 0%)
#   adding: a/im010050.png (stored 0%)
#   adding: a/im018102.png (stored 0%)
#   adding: a/im015186.png (stored 0%)
#   adding: a/im014931.png (stored 0%)
#   adding: a/im017970.png (stored 0%)
#   adding: a/im017926.png (stored 0%)
#   adding: a/im011673.png (stored 0%)
#   adding: a/im018294.png (stored 0%)
#   adding: a/im016597.png (stored 0%)
#   adding: a/im017303.png (stored 0%)
#   adding: a/im017738.png (stored 0%)
#   adding: a/im017729.png (stored 0%)
#   adding: a/im012381.png (stored 0%)
#   adding: a/im012383.png (stored 0%)
#   adding: a/im017320.png (stored 0%)
#   adding: a/im010018.png (stored 0%)
#   adding: a/im017524.png (stored 0%)
#   adding: a/im012774.png (stored 0%)
#   adding: a/im013221.png (stored 0%)
#   adding: a/im014572.png (stored 0%)
#   adding: a/im013635.png (stored 0%)
#   adding: a/im015025.png (stored 0%)
#   adding: a/im011075.png (stored 0%)
#   adding: a/im018313.png (stored 0%)
#   adding: a/im016962.png (stored 0%)
#   adding: a/im010767.png (stored 0%)
#   adding: a/im014887.png (stored 0%)
#   adding: a/im010080.png (stored 0%)
#   adding: a/im013314.png (stored 0%)
#   adding: a/im010592.png (stored 0%)
#   adding: a/im016566.png (stored 0%)
#   adding: a/im015112.png (stored 0%)
#   adding: a/im018148.png (stored 0%)
#   adding: a/im019020.png (stored 0%)
#   adding: a/im013376.png (stored 0%)
#   adding: a/im010737.png (stored 0%)
#   adding: a/im015551.png (stored 0%)
#   adding: a/im016131.png (stored 0%)
#   adding: a/im019117.png (stored 0%)
#   adding: a/im014023.png (stored 0%)
#   adding: a/im019004.png (stored 0%)
#   adding: a/im011860.png (stored 0%)
#   adding: a/im017917.png (stored 0%)
#   adding: a/im014776.png (stored 0%)
#   adding: a/im017477.png (stored 0%)
#   adding: a/im019230.png (stored 0%)
#   adding: a/im015502.png (stored 0%)
#   adding: a/im015406.png (stored 0%)
#   adding: a/im013469.png (stored 0%)
#   adding: a/im010041.png (stored 0%)
#   adding: a/im013671.png (stored 0%)
#   adding: a/im014470.png (stored 0%)
#   adding: a/im013028.png (stored 0%)
#   adding: a/im019025.png (stored 0%)
#   adding: a/im014465.png (stored 0%)
#   adding: a/im019123.png (stored 0%)
#   adding: a/im010259.png (stored 0%)
#   adding: a/im010926.png (stored 0%)
#   adding: a/im018328.png (stored 0%)
#   adding: a/im013982.png (stored 0%)
#   adding: a/im016826.png (stored 0%)
#   adding: a/im018128.png (stored 0%)
#   adding: a/im013450.png (stored 0%)
#   adding: a/im018566.png (stored 0%)
#   adding: a/im017998.png (stored 0%)
#   adding: a/im019496.png (stored 0%)
#   adding: a/im012244.png (stored 0%)
#   adding: a/im017971.png (stored 0%)
#   adding: a/im011327.png (stored 0%)
#   adding: a/im013207.png (stored 0%)
#   adding: a/im010023.png (stored 0%)
#   adding: a/im017299.png (stored 0%)
#   adding: a/im013460.png (stored 0%)
#   adding: a/im013393.png (stored 0%)
#   adding: a/im018161.png (stored 0%)
#   adding: a/im017582.png (stored 0%)
#   adding: a/im011464.png (stored 0%)
#   adding: a/im012559.png (stored 0%)
#   adding: a/im010156.png (stored 0%)
#   adding: a/im010358.png (stored 0%)
#   adding: a/im019160.png (stored 0%)
#   adding: a/im011612.png (stored 0%)
#   adding: a/im012823.png (stored 0%)
#   adding: a/im013779.png (stored 0%)
#   adding: a/im017664.png (stored 0%)
#   adding: a/im014655.png (stored 0%)
#   adding: a/im017326.png (stored 0%)
#   adding: a/im015422.png (stored 0%)
#   adding: a/im011797.png (stored 0%)
#   adding: a/im015318.png (stored 0%)
#   adding: a/im013618.png (stored 0%)
#   adding: a/im017655.png (stored 0%)
#   adding: a/im012808.png (stored 0%)
#   adding: a/im014484.png (stored 0%)
#   adding: a/im010472.png (stored 0%)
#   adding: a/im011788.png (stored 0%)
#   adding: a/im010655.png (stored 0%)
#   adding: a/im013642.png (stored 0%)
#   adding: a/im018849.png (stored 0%)
#   adding: a/im015948.png (stored 0%)
#   adding: a/im012177.png (stored 0%)
#   adding: a/im018257.png (stored 0%)
#   adding: a/im010639.png (stored 0%)
#   adding: a/im013877.png (stored 0%)
#   adding: a/im010395.png (stored 0%)
#   adding: a/im016606.png (stored 0%)
#   adding: a/im012382.png (stored 0%)
#   adding: a/im018538.png (stored 0%)
#   adding: a/im012309.png (stored 0%)
#   adding: a/im018762.png (stored 0%)
#   adding: a/im010448.png (stored 0%)
#   adding: a/im019981.png (stored 0%)
#   adding: a/im010192.png (stored 0%)
#   adding: a/im011245.png (stored 0%)
#   adding: a/im013273.png (stored 0%)
#   adding: a/im015405.png (stored 0%)
#   adding: a/im012925.png (stored 0%)
#   adding: a/im013619.png (stored 0%)
#   adding: a/im010788.png (stored 0%)
#   adding: a/im011476.png (stored 0%)
#   adding: a/im014273.png (stored 0%)
#   adding: a/im017318.png (stored 0%)
#   adding: a/im019055.png (stored 0%)
#   adding: a/im019017.png (stored 0%)
#   adding: a/im011556.png (stored 0%)
#   adding: a/im012623.png (stored 0%)
#   adding: a/im018253.png (stored 0%)
#   adding: a/im012041.png (stored 0%)
#   adding: a/im011082.png (stored 0%)
#   adding: a/im011620.png (stored 0%)
#   adding: a/im014595.png (stored 0%)
#   adding: a/im010808.png (stored 0%)
#   adding: a/im016242.png (stored 0%)
#   adding: a/im019135.png (stored 0%)
#   adding: a/im016410.png (stored 0%)
#   adding: a/im011284.png (stored 0%)
#   adding: a/im010366.png (stored 0%)
#   adding: a/im017431.png (stored 0%)
#   adding: a/im012263.png (stored 0%)
#   adding: a/im012410.png (stored 0%)
#   adding: a/im015022.png (stored 0%)
#   adding: a/im014976.png (stored 0%)
#   adding: a/im011315.png (stored 0%)
#   adding: a/im012910.png (stored 0%)
#   adding: a/im015684.png (stored 0%)
#   adding: a/im014190.png (stored 0%)
#   adding: a/im014286.png (stored 0%)
#   adding: a/im015739.png (stored 0%)
#   adding: a/im010048.png (stored 0%)
#   adding: a/im010541.png (stored 0%)
#   adding: a/im012023.png (stored 0%)
#   adding: a/im017206.png (stored 0%)
#   adding: a/im019064.png (stored 0%)
#   adding: a/im019922.png (stored 0%)
#   adding: a/im014511.png (stored 0%)
#   adding: a/im013509.png (stored 0%)
#   adding: a/im015274.png (stored 0%)
#   adding: a/im013140.png (stored 0%)
#   adding: a/im014037.png (stored 0%)
#   adding: a/im019045.png (stored 0%)
#   adding: a/im018433.png (stored 0%)
#   adding: a/im012558.png (stored 0%)
#   adding: a/im011661.png (stored 0%)
#   adding: a/im014721.png (stored 0%)
#   adding: a/im011120.png (stored 0%)
#   adding: a/im013545.png (stored 0%)
#   adding: a/im013723.png (stored 0%)
#   adding: a/im012963.png (stored 0%)
#   adding: a/im019480.png (stored 0%)
#   adding: a/im012363.png (stored 0%)
#   adding: a/im012203.png (stored 0%)
#   adding: a/im019446.png (stored 0%)
#   adding: a/im017023.png (stored 0%)
#   adding: a/im012485.png (stored 0%)
#   adding: a/im016942.png (stored 0%)
#   adding: a/im014591.png (stored 0%)
#   adding: a/im019215.png (stored 0%)
#   adding: a/im018711.png (stored 0%)
#   adding: a/im014651.png (stored 0%)
#   adding: a/im014814.png (stored 0%)
#   adding: a/im016899.png (stored 0%)
#   adding: a/im015911.png (stored 0%)
#   adding: a/im017231.png (stored 0%)
#   adding: a/im010667.png (stored 0%)
#   adding: a/im015447.png (stored 0%)
#   adding: a/im019908.png (stored 0%)
#   adding: a/im011559.png (stored 0%)
#   adding: a/im013550.png (stored 0%)
#   adding: a/im012817.png (stored 0%)
#   adding: a/im017693.png (stored 0%)
#   adding: a/im013415.png (stored 0%)
#   adding: a/im018493.png (stored 0%)
#   adding: a/im011674.png (stored 0%)
#   adding: a/im017173.png (stored 0%)
#   adding: a/im015460.png (stored 0%)
#   adding: a/im013227.png (stored 0%)
#   adding: a/im012986.png (stored 0%)
#   adding: a/im019353.png (stored 0%)
#   adding: a/im015014.png (stored 0%)
#   adding: a/im018162.png (stored 0%)
#   adding: a/im011866.png (stored 0%)
#   adding: a/im017217.png (stored 0%)
#   adding: a/im012398.png (stored 0%)
#   adding: a/im010731.png (stored 0%)
#   adding: a/im014166.png (stored 0%)
#   adding: a/im011828.png (stored 0%)
#   adding: a/im015136.png (stored 0%)
#   adding: a/im016268.png (stored 0%)
#   adding: a/im018857.png (stored 0%)
#   adding: a/im019336.png (stored 0%)
#   adding: a/im013609.png (stored 0%)
#   adding: a/im017692.png (stored 0%)
#   adding: a/im010106.png (stored 0%)
#   adding: a/im017274.png (stored 0%)
#   adding: a/im015251.png (stored 0%)
#   adding: a/im011895.png (stored 0%)
#   adding: a/im018050.png (stored 0%)
#   adding: a/im018792.png (stored 0%)
#   adding: a/im010758.png (stored 0%)
#   adding: a/im018541.png (stored 0%)
#   adding: a/im018991.png (stored 0%)
#   adding: a/im017961.png (stored 0%)
#   adding: a/im013716.png (stored 0%)
#   adding: a/im018232.png (stored 0%)
#   adding: a/im010411.png (stored 0%)
#   adding: a/im013288.png (stored 0%)
#   adding: a/im014613.png (stored 0%)
#   adding: a/im013995.png (stored 0%)
#   adding: a/im010671.png (stored 0%)
#   adding: a/im012551.png (stored 0%)
#   adding: a/im019594.png (stored 0%)
#   adding: a/im012588.png (stored 0%)
#   adding: a/im014892.png (stored 0%)
#   adding: a/im012362.png (stored 0%)
#   adding: a/im017807.png (stored 0%)
#   adding: a/im018710.png (stored 0%)
#   adding: a/im013949.png (stored 0%)
#   adding: a/im012796.png (stored 0%)
#   adding: a/im013561.png (stored 0%)
#   adding: a/im010915.png (stored 0%)
#   adding: a/im015084.png (stored 0%)
#   adding: a/im014161.png (stored 0%)
#   adding: a/im018745.png (stored 0%)
#   adding: a/im010994.png (stored 0%)
#   adding: a/im014411.png (stored 0%)
#   adding: a/im017497.png (stored 0%)
#   adding: a/im010386.png (stored 0%)
#   adding: a/im011210.png (stored 0%)
#   adding: a/im017249.png (stored 0%)
#   adding: a/im018188.png (stored 0%)
#   adding: a/im019358.png (stored 0%)
#   adding: a/im019632.png (stored 0%)
#   adding: a/im016874.png (stored 0%)
#   adding: a/im018802.png (stored 0%)
#   adding: a/im017889.png (stored 0%)
#   adding: a/im017771.png (stored 0%)
#   adding: a/im015884.png (stored 0%)
#   adding: a/im013834.png (stored 0%)
#   adding: a/im012416.png (stored 0%)
#   adding: a/im011485.png (stored 0%)
#   adding: a/im012981.png (stored 0%)
#   adding: a/im015151.png (stored 0%)
#   adding: a/im011102.png (stored 0%)
#   adding: a/im014006.png (stored 0%)
#   adding: a/im019452.png (stored 0%)
#   adding: a/im014206.png (stored 0%)
#   adding: a/im019109.png (stored 0%)
#   adding: a/im018629.png (stored 0%)
#   adding: a/im015436.png (stored 0%)
#   adding: a/im010076.png (stored 0%)
#   adding: a/im012920.png (stored 0%)
#   adding: a/im016629.png (stored 0%)
#   adding: a/im016544.png (stored 0%)
#   adding: a/im011782.png (stored 0%)
#   adding: a/im016463.png (stored 0%)
#   adding: a/im019036.png (stored 0%)
#   adding: a/im015687.png (stored 0%)
#   adding: a/im012483.png (stored 0%)
#   adding: a/im010688.png (stored 0%)
#   adding: a/im013102.png (stored 0%)
#   adding: a/im014598.png (stored 0%)
#   adding: a/im016004.png (stored 0%)
#   adding: a/im018489.png (stored 0%)
#   adding: a/im013890.png (stored 0%)
#   adding: a/im017053.png (stored 0%)
#   adding: a/im012715.png (stored 0%)
#   adding: a/im015462.png (stored 0%)
#   adding: a/im010130.png (stored 0%)
#   adding: a/im012946.png (stored 0%)
#   adding: a/im011462.png (stored 0%)
#   adding: a/im010377.png (stored 0%)
#   adding: a/im017969.png (stored 0%)
#   adding: a/im018527.png (stored 0%)
#   adding: a/im015622.png (stored 0%)
#   adding: a/im017647.png (stored 0%)
#   adding: a/im013413.png (stored 0%)
#   adding: a/im018484.png (stored 0%)
#   adding: a/im014021.png (stored 0%)
#   adding: a/im013667.png (stored 0%)
#   adding: a/im015833.png (stored 0%)
#   adding: a/im011274.png (stored 0%)
#   adding: a/im010385.png (stored 0%)
#   adding: a/im013138.png (stored 0%)
#   adding: a/im015656.png (stored 0%)
#   adding: a/im013519.png (stored 0%)
#   adding: a/im011405.png (stored 0%)
#   adding: a/im019350.png (stored 0%)
#   adding: a/im010605.png (stored 0%)
#   adding: a/im015359.png (stored 0%)
#   adding: a/im013553.png (stored 0%)
#   adding: a/im018113.png (stored 0%)
#   adding: a/im017155.png (stored 0%)
#   adding: a/im014624.png (stored 0%)
#   adding: a/im011739.png (stored 0%)
#   adding: a/im019046.png (stored 0%)
#   adding: a/im014569.png (stored 0%)
#   adding: a/im015867.png (stored 0%)
#   adding: a/im010985.png (stored 0%)
#   adding: a/im019056.png (stored 0%)
#   adding: a/im016937.png (stored 0%)
#   adding: a/im010185.png (stored 0%)
#   adding: a/im016897.png (stored 0%)
#   adding: a/im016591.png (stored 0%)
#   adding: a/im011258.png (stored 0%)
#   adding: a/im018385.png (stored 0%)
#   adding: a/im012204.png (stored 0%)
#   adding: a/im011632.png (stored 0%)
#   adding: a/im012058.png (stored 0%)
#   adding: a/im013104.png (stored 0%)
#   adding: a/im011961.png (stored 0%)
#   adding: a/im013096.png (stored 0%)
#   adding: a/im012517.png (stored 0%)
#   adding: a/im010556.png (stored 0%)
#   adding: a/im010295.png (stored 0%)
#   adding: a/im015752.png (stored 0%)
#   adding: a/im015201.png (stored 0%)
#   adding: a/im012031.png (stored 0%)
#   adding: a/im012648.png (stored 0%)
#   adding: a/im010104.png (stored 0%)
#   adding: a/im016369.png (stored 0%)
#   adding: a/im011281.png (stored 0%)
#   adding: a/im016444.png (stored 0%)
#   adding: a/im017688.png (stored 0%)
#   adding: a/im015810.png (stored 0%)
#   adding: a/im014126.png (stored 0%)
#   adding: a/im014347.png (stored 0%)
#   adding: a/im010899.png (stored 0%)
#   adding: a/im010433.png (stored 0%)
#   adding: a/im012768.png (stored 0%)
#   adding: a/im016494.png (stored 0%)
#   adding: a/im018276.png (stored 0%)
#   adding: a/im011130.png (stored 0%)
#   adding: a/im016417.png (stored 0%)
#   adding: a/im019088.png (stored 0%)
#   adding: a/im017993.png (stored 0%)
#   adding: a/im011272.png (stored 0%)
#   adding: a/im013896.png (stored 0%)
#   adding: a/im018940.png (stored 0%)
#   adding: a/im010939.png (stored 0%)
#   adding: a/im010201.png (stored 0%)
#   adding: a/im011974.png (stored 0%)
#   adding: a/im010609.png (stored 0%)
#   adding: a/im014127.png (stored 0%)
#   adding: a/im013538.png (stored 0%)
#   adding: a/im010073.png (stored 0%)
#   adding: a/im011456.png (stored 0%)
#   adding: a/im018043.png (stored 0%)
#   adding: a/im015069.png (stored 0%)
#   adding: a/im015793.png (stored 0%)
#   adding: a/im013378.png (stored 0%)
#   adding: a/im013530.png (stored 0%)
#   adding: a/im011701.png (stored 0%)
#   adding: a/im013279.png (stored 0%)
#   adding: a/im018994.png (stored 0%)
#   adding: a/im017830.png (stored 0%)
#   adding: a/im015758.png (stored 0%)
#   adding: a/im014344.png (stored 0%)
#   adding: a/im018964.png (stored 0%)
#   adding: a/im015082.png (stored 0%)
#   adding: a/im013392.png (stored 0%)
#   adding: a/im016717.png (stored 0%)
#   adding: a/im011902.png (stored 0%)
#   adding: a/im018946.png (stored 0%)
#   adding: a/im014671.png (stored 0%)
#   adding: a/im017666.png (stored 0%)
#   adding: a/im018325.png (stored 0%)
#   adding: a/im016167.png (stored 0%)
#   adding: a/im017507.png (stored 0%)
#   adding: a/im018783.png (stored 0%)
#   adding: a/im019754.png (stored 0%)
#   adding: a/im014521.png (stored 0%)
#   adding: a/im011664.png (stored 0%)
#   adding: a/im015172.png (stored 0%)
#   adding: a/im013367.png (stored 0%)
#   adding: a/im013497.png (stored 0%)
#   adding: a/im013885.png (stored 0%)
#   adding: a/im017718.png (stored 0%)
#   adding: a/im010044.png (stored 0%)
#   adding: a/im011440.png (stored 0%)
#   adding: a/im010449.png (stored 0%)
#   adding: a/im017964.png (stored 0%)
#   adding: a/im016971.png (stored 0%)
#   adding: a/im016297.png (stored 0%)
#   adding: a/im010937.png (stored 0%)
#   adding: a/im017559.png (stored 0%)
#   adding: a/im019303.png (stored 0%)
#   adding: a/im017619.png (stored 0%)
#   adding: a/im010997.png (stored 0%)
#   adding: a/im012781.png (stored 0%)
#   adding: a/im017124.png (stored 0%)
#   adding: a/im015675.png (stored 0%)
#   adding: a/im011715.png (stored 0%)
#   adding: a/im018500.png (stored 0%)
#   adding: a/im015612.png (stored 0%)
#   adding: a/im013493.png (stored 0%)
#   adding: a/im011151.png (stored 0%)
#   adding: a/im018631.png (stored 0%)
#   adding: a/im012659.png (stored 0%)
#   adding: a/im019478.png (stored 0%)
#   adding: a/im013852.png (stored 0%)
#   adding: a/im012055.png (stored 0%)
#   adding: a/im016746.png (stored 0%)
#   adding: a/im013011.png (stored 0%)
#   adding: a/im016491.png (stored 0%)
#   adding: a/im011431.png (stored 0%)
#   adding: a/im014408.png (stored 0%)
#   adding: a/im011527.png (stored 0%)
#   adding: a/im017289.png (stored 0%)
#   adding: a/im015790.png (stored 0%)
#   adding: a/im010794.png (stored 0%)
#   adding: a/im016223.png (stored 0%)
#   adding: a/im014846.png (stored 0%)
#   adding: a/im017606.png (stored 0%)
#   adding: a/im017800.png (stored 0%)
#   adding: a/im011546.png (stored 0%)
#   adding: a/im015711.png (stored 0%)
#   adding: a/im014462.png (stored 0%)
#   adding: a/im010206.png (stored 0%)
#   adding: a/im014964.png (stored 0%)
#   adding: a/im014727.png (stored 0%)
#   adding: a/im015492.png (stored 0%)
#   adding: a/im013482.png (stored 0%)
#   adding: a/im019812.png (stored 0%)
#   adding: a/im014001.png (stored 0%)
#   adding: a/im015375.png (stored 0%)
#   adding: a/im011526.png (stored 0%)
#   adding: a/im012375.png (stored 0%)
#   adding: a/im010564.png (stored 0%)
#   adding: a/im017896.png (stored 0%)
#   adding: a/im017004.png (stored 0%)
#   adding: a/im013145.png (stored 0%)
#   adding: a/im011407.png (stored 0%)
#   adding: a/im015747.png (stored 0%)
#   adding: a/im016802.png (stored 0%)
#   adding: a/im019885.png (stored 0%)
#   adding: a/im010463.png (stored 0%)
#   adding: a/im017461.png (stored 0%)
#   adding: a/im015734.png (stored 0%)
#   adding: a/im014658.png (stored 0%)
#   adding: a/im012390.png (stored 0%)
#   adding: a/im014276.png (stored 0%)
#   adding: a/im015749.png (stored 0%)
#   adding: a/im010354.png (stored 0%)
#   adding: a/im011436.png (stored 0%)
#   adding: a/im019723.png (stored 0%)
#   adding: a/im012857.png (stored 0%)
#   adding: a/im016102.png (stored 0%)
#   adding: a/im013110.png (stored 0%)
#   adding: a/im011705.png (stored 0%)
#   adding: a/im017699.png (stored 0%)
#   adding: a/im010281.png (stored 0%)
#   adding: a/im017453.png (stored 0%)
#   adding: a/im010841.png (stored 0%)
#   adding: a/im014646.png (stored 0%)
#   adding: a/im016001.png (stored 0%)
#   adding: a/im016844.png (stored 0%)
#   adding: a/im015980.png (stored 0%)
#   adding: a/im011101.png (stored 0%)
#   adding: a/im012492.png (stored 0%)
#   adding: a/im014158.png (stored 0%)
#   adding: a/im015831.png (stored 0%)
#   adding: a/im017752.png (stored 0%)
#   adding: a/im018669.png (stored 0%)
#   adding: a/im014860.png (stored 0%)
#   adding: a/im012895.png (stored 0%)
#   adding: a/im018654.png (stored 0%)
#   adding: a/im017119.png (stored 0%)
#   adding: a/im017233.png (stored 0%)
#   adding: a/im016390.png (stored 0%)
#   adding: a/im015210.png (stored 0%)
#   adding: a/im013856.png (stored 0%)
#   adding: a/im019614.png (stored 0%)
#   adding: a/im011446.png (stored 0%)
#   adding: a/im010410.png (stored 0%)
#   adding: a/im017393.png (stored 0%)
#   adding: a/im012124.png (stored 0%)
#   adding: a/im010306.png (stored 0%)
#   adding: a/im011279.png (stored 0%)
#   adding: a/im016979.png (stored 0%)
#   adding: a/im013568.png (stored 0%)
#   adding: a/im018644.png (stored 0%)
#   adding: a/im017033.png (stored 0%)
#   adding: a/im012854.png (stored 0%)
#   adding: a/im012475.png (stored 0%)
#   adding: a/im019706.png (stored 0%)
#   adding: a/im013632.png (stored 0%)
#   adding: a/im013971.png (stored 0%)
#   adding: a/im019966.png (stored 0%)
#   adding: a/im019698.png (stored 0%)
#   adding: a/im017479.png (stored 0%)
#   adding: a/im019579.png (stored 0%)
#   adding: a/im013756.png (stored 0%)
#   adding: a/im014904.png (stored 0%)
#   adding: a/im012418.png (stored 0%)
#   adding: a/im015890.png (stored 0%)
#   adding: a/im012814.png (stored 0%)
#   adding: a/im018019.png (stored 0%)
#   adding: a/im010294.png (stored 0%)
#   adding: a/im019457.png (stored 0%)
#   adding: a/im016500.png (stored 0%)
#   adding: a/im015073.png (stored 0%)
#   adding: a/im013813.png (stored 0%)
#   adding: a/im016570.png (stored 0%)
#   adding: a/im015488.png (stored 0%)
#   adding: a/im013789.png (stored 0%)
#   adding: a/im013177.png (stored 0%)
#   adding: a/im010636.png (stored 0%)
#   adding: a/im012572.png (stored 0%)
#   adding: a/im018237.png (stored 0%)
#   adding: a/im012028.png (stored 0%)
#   adding: a/im014670.png (stored 0%)
#   adding: a/im014635.png (stored 0%)
#   adding: a/im014588.png (stored 0%)
#   adding: a/im011998.png (stored 0%)
#   adding: a/im011725.png (stored 0%)
#   adding: a/im016429.png (stored 0%)
#   adding: a/im019477.png (stored 0%)
#   adding: a/im015662.png (stored 0%)
#   adding: a/im017615.png (stored 0%)
#   adding: a/im018828.png (stored 0%)
#   adding: a/im019405.png (stored 0%)
#   adding: a/im010883.png (stored 0%)
#   adding: a/im018166.png (stored 0%)
#   adding: a/im015642.png (stored 0%)
#   adding: a/im014065.png (stored 0%)
#   adding: a/im019408.png (stored 0%)
#   adding: a/im016493.png (stored 0%)
#   adding: a/im012259.png (stored 0%)
#   adding: a/im012141.png (stored 0%)
#   adding: a/im012615.png (stored 0%)
#   adding: a/im011789.png (stored 0%)
#   adding: a/im010604.png (stored 0%)
#   adding: a/im015095.png (stored 0%)
#   adding: a/im018355.png (stored 0%)
#   adding: a/im013953.png (stored 0%)
#   adding: a/im014201.png (stored 0%)
#   adding: a/im016784.png (stored 0%)
#   adding: a/im015794.png (stored 0%)
#   adding: a/im019210.png (stored 0%)
#   adding: a/im015282.png (stored 0%)
#   adding: a/im014854.png (stored 0%)
#   adding: a/im013918.png (stored 0%)
#   adding: a/im012844.png (stored 0%)
#   adding: a/im010365.png (stored 0%)
#   adding: a/im016842.png (stored 0%)
#   adding: a/im018643.png (stored 0%)
#   adding: a/im014941.png (stored 0%)
#   adding: a/im015411.png (stored 0%)
#   adding: a/im010546.png (stored 0%)
#   adding: a/im019222.png (stored 0%)
#   adding: a/im012855.png (stored 0%)
#   adding: a/im015211.png (stored 0%)
#   adding: a/im011401.png (stored 0%)
#   adding: a/im012035.png (stored 0%)
#   adding: a/im010051.png (stored 0%)
#   adding: a/im014355.png (stored 0%)
#   adding: a/im016471.png (stored 0%)
#   adding: a/im011950.png (stored 0%)
#   adding: a/im012369.png (stored 0%)
#   adding: a/im019548.png (stored 0%)
#   adding: a/im015131.png (stored 0%)
#   adding: a/im017772.png (stored 0%)
#   adding: a/im010998.png (stored 0%)
#   adding: a/im018471.png (stored 0%)
#   adding: a/im015213.png (stored 0%)
#   adding: a/im012178.png (stored 0%)
#   adding: a/im015665.png (stored 0%)
#   adding: a/im012292.png (stored 0%)
#   adding: a/im018939.png (stored 0%)
#   adding: a/im013854.png (stored 0%)
#   adding: a/im016923.png (stored 0%)
#   adding: a/im017240.png (stored 0%)
#   adding: a/im015336.png (stored 0%)
#   adding: a/im016904.png (stored 0%)
#   adding: a/im012688.png (stored 0%)
#   adding: a/im016088.png (stored 0%)
#   adding: a/im015952.png (stored 0%)
#   adding: a/im016136.png (stored 0%)
#   adding: a/im014513.png (stored 0%)
#   adding: a/im017304.png (stored 0%)
#   adding: a/im017285.png (stored 0%)
#   adding: a/im014844.png (stored 0%)
#   adding: a/im015018.png (stored 0%)
#   adding: a/im010753.png (stored 0%)
#   adding: a/im017402.png (stored 0%)
#   adding: a/im013717.png (stored 0%)
#   adding: a/im012561.png (stored 0%)
#   adding: a/im015368.png (stored 0%)
#   adding: a/im016922.png (stored 0%)
#   adding: a/im018135.png (stored 0%)
#   adding: a/im019029.png (stored 0%)
#   adding: a/im014247.png (stored 0%)
#   adding: a/im019979.png (stored 0%)
#   adding: a/im013828.png (stored 0%)
#   adding: a/im017725.png (stored 0%)
#   adding: a/im019155.png (stored 0%)
#   adding: a/im015568.png (stored 0%)
#   adding: a/im011678.png (stored 0%)
#   adding: a/im016822.png (stored 0%)
#   adding: a/im014225.png (stored 0%)
#   adding: a/im013334.png (stored 0%)
#   adding: a/im017475.png (stored 0%)
#   adding: a/im014894.png (stored 0%)
#   adding: a/im019280.png (stored 0%)
#   adding: a/im012780.png (stored 0%)
#   adding: a/im015366.png (stored 0%)
#   adding: a/im013525.png (stored 0%)
#   adding: a/im017447.png (stored 0%)
#   adding: a/im019654.png (stored 0%)
#   adding: a/im010152.png (stored 0%)
#   adding: a/im010453.png (stored 0%)
#   adding: a/im010527.png (stored 0%)
#   adding: a/im011625.png (stored 0%)
#   adding: a/im010941.png (stored 0%)
#   adding: a/im012209.png (stored 0%)
#   adding: a/im016984.png (stored 0%)
#   adding: a/im014668.png (stored 0%)
#   adding: a/im011406.png (stored 0%)
#   adding: a/im019335.png (stored 0%)
#   adding: a/im010212.png (stored 0%)
#   adding: a/im019945.png (stored 0%)
#   adding: a/im019964.png (stored 0%)
#   adding: a/im018821.png (stored 0%)
#   adding: a/im014195.png (stored 0%)
#   adding: a/im010748.png (stored 0%)
#   adding: a/im016011.png (stored 0%)
#   adding: a/im011807.png (stored 0%)
#   adding: a/im013466.png (stored 0%)
#   adding: a/im014859.png (stored 0%)
#   adding: a/im016686.png (stored 0%)
#   adding: a/im018213.png (stored 0%)
#   adding: a/im013845.png (stored 0%)
#   adding: a/im010735.png (stored 0%)
#   adding: a/im013099.png (stored 0%)
#   adding: a/im019077.png (stored 0%)
#   adding: a/im010245.png (stored 0%)
#   adding: a/im017634.png (stored 0%)
#   adding: a/im015671.png (stored 0%)
#   adding: a/im012722.png (stored 0%)
#   adding: a/im017448.png (stored 0%)
#   adding: a/im012604.png (stored 0%)
#   adding: a/im018561.png (stored 0%)
#   adding: a/im016621.png (stored 0%)
#   adding: a/im012486.png (stored 0%)
#   adding: a/im015074.png (stored 0%)
#   adding: a/im018295.png (stored 0%)
#   adding: a/im017536.png (stored 0%)
#   adding: a/im015370.png (stored 0%)
# ...
#   adding: a/im013108.png (stored 0%)
#   adding: a/im015947.png (stored 0%)
#   adding: a/im015938.png (stored 0%)
#   adding: a/im014592.png (stored 0%)
#   adding: a/im012270.png (stored 0%)
#   adding: a/im016881.png (stored 0%)
#   adding: a/im016234.png (stored 0%)
#   adding: a/im017355.png (stored 0%)
#   adding: a/im011117.png (stored 0%)
#   adding: a/im014144.png (stored 0%)
#   adding: a/im019021.png (stored 0%)
#   adding: a/im019163.png (stored 0%)
#   adding: a/im013990.png (stored 0%)
#   adding: a/im015550.png (stored 0%)
#   adding: a/im010315.png (stored 0%)
#   adding: a/im019989.png (stored 0%)
#   adding: a/im012212.png (stored 0%)
#   adding: a/im014398.png (stored 0%)
#   adding: a/im013321.png (stored 0%)
#   adding: a/im014574.png (stored 0%)
#   adding: a/im014387.png (stored 0%)
#   adding: a/im011815.png (stored 0%)
#   adding: a/im011397.png (stored 0%)
#   adding: a/im017133.png (stored 0%)
#   adding: a/im019460.png (stored 0%)
#   adding: a/im015348.png (stored 0%)
#   adding: a/im011838.png (stored 0%)
#   adding: a/im013670.png (stored 0%)
#   adding: a/im018236.png (stored 0%)
#   adding: a/im010045.png (stored 0%)
#   adding: a/im017515.png (stored 0%)
#   adding: a/im018233.png (stored 0%)
#   adding: a/im013143.png (stored 0%)
#   adding: a/im016831.png (stored 0%)
#   adding: a/im019552.png (stored 0%)
#   adding: a/im011185.png (stored 0%)
#   adding: a/im013638.png (stored 0%)
#   adding: a/im016632.png (stored 0%)
#   adding: a/im015588.png (stored 0%)
#   adding: a/im016230.png (stored 0%)
#   adding: a/im011529.png (stored 0%)
#   adding: a/im018791.png (stored 0%)
#   adding: a/im019323.png (stored 0%)
#   adding: a/im019651.png (stored 0%)
#   adding: a/im010085.png (stored 0%)
#   adding: a/im013806.png (stored 0%)
#   adding: a/im014016.png (stored 0%)
#   adding: a/im016094.png (stored 0%)
#   adding: a/im015338.png (stored 0%)
#   adding: a/im012829.png (stored 0%)
#   adding: a/im015951.png (stored 0%)
#   adding: a/im012995.png (stored 0%)
#   adding: a/im010029.png (stored 0%)
#   adding: a/im013907.png (stored 0%)
#   adding: a/im016692.png (stored 0%)
#   adding: a/im016181.png (stored 0%)
#   adding: a/im019557.png (stored 0%)
#   adding: a/im010534.png (stored 0%)
#   adding: a/im017202.png (stored 0%)
#   adding: a/im015360.png (stored 0%)
#   adding: a/im019663.png (stored 0%)
#   adding: a/im012709.png (stored 0%)
#   adding: a/im011547.png (stored 0%)
#   adding: a/im014471.png (stored 0%)
#   adding: a/im018401.png (stored 0%)
#   adding: a/im012004.png (stored 0%)
#   adding: a/im012769.png (stored 0%)
#   adding: a/im011138.png (stored 0%)
#   adding: a/im015542.png (stored 0%)
#   adding: a/im013023.png (stored 0%)
#   adding: a/im013222.png (stored 0%)
#   adding: a/im012554.png (stored 0%)
#   adding: a/im015870.png (stored 0%)
#   adding: a/im013441.png (stored 0%)
#   adding: a/im017210.png (stored 0%)
#   adding: a/im017791.png (stored 0%)
#   adding: a/im014989.png (stored 0%)
#   adding: a/im019066.png (stored 0%)
#   adding: a/im017623.png (stored 0%)
#   adding: a/im013812.png (stored 0%)
#   adding: a/im014587.png (stored 0%)
#   adding: a/im019190.png (stored 0%)
#   adding: a/im013910.png (stored 0%)
#   adding: a/im013075.png (stored 0%)
#   adding: a/im018738.png (stored 0%)
#   adding: a/im010054.png (stored 0%)
#   adding: a/im016332.png (stored 0%)
#   adding: a/im013689.png (stored 0%)
#   adding: a/im019988.png (stored 0%)
#   adding: a/im013621.png (stored 0%)
#   adding: a/im015192.png (stored 0%)
#   adding: a/im014209.png (stored 0%)
#   adding: a/im010190.png (stored 0%)
#   adding: a/im019818.png (stored 0%)
#   adding: a/im018957.png (stored 0%)
#   adding: a/im013815.png (stored 0%)
#   adding: a/im011927.png (stored 0%)
#   adding: a/im012226.png (stored 0%)
#   adding: a/im011639.png (stored 0%)
#   adding: a/im015185.png (stored 0%)
#   adding: a/im014560.png (stored 0%)
#   adding: a/im012538.png (stored 0%)
#   adding: a/im016614.png (stored 0%)
#   adding: a/im015024.png (stored 0%)
#   adding: a/im015997.png (stored 0%)
#   adding: a/im019839.png (stored 0%)
#   adding: a/im015062.png (stored 0%)
#   adding: a/im010577.png (stored 0%)
#   adding: a/im016748.png (stored 0%)
#   adding: a/im013409.png (stored 0%)
#   adding: a/im013358.png (stored 0%)
#   adding: a/im017558.png (stored 0%)
#   adding: a/im013000.png (stored 0%)
#   adding: a/im011762.png (stored 0%)
#   adding: a/im019782.png (stored 0%)
#   adding: a/im016324.png (stored 0%)
#   adding: a/im011759.png (stored 0%)
#   adding: a/im019529.png (stored 0%)
#   adding: a/im018291.png (stored 0%)
#   adding: a/im017721.png (stored 0%)
#   adding: a/im018032.png (stored 0%)
#   adding: a/im012533.png (stored 0%)
#   adding: a/im016375.png (stored 0%)
#   adding: a/im013688.png (stored 0%)
#   adding: a/im013775.png (stored 0%)
#   adding: a/im012642.png (stored 0%)
#   adding: a/im019208.png (stored 0%)
#   adding: a/im015547.png (stored 0%)
#   adding: a/im016637.png (stored 0%)
#   adding: a/im014838.png (stored 0%)
#   adding: a/im011951.png (stored 0%)
#   adding: a/im010678.png (stored 0%)
#   adding: a/im010851.png (stored 0%)
#   adding: a/im015217.png (stored 0%)
#   adding: a/im012047.png (stored 0%)
#   adding: a/im012128.png (stored 0%)
#   adding: a/im018164.png (stored 0%)
#   adding: a/im013013.png (stored 0%)
#   adding: a/im012480.png (stored 0%)
#   adding: a/im016845.png (stored 0%)
#   adding: a/im010207.png (stored 0%)
#   adding: a/im016411.png (stored 0%)
#   adding: a/im016209.png (stored 0%)
#   adding: a/im017873.png (stored 0%)
#   adding: a/im011270.png (stored 0%)
#   adding: a/im018600.png (stored 0%)
#   adding: a/im011348.png (stored 0%)
#   adding: a/im018005.png (stored 0%)
#   adding: a/im015463.png (stored 0%)
#   adding: a/im018465.png (stored 0%)
#   adding: a/im017183.png (stored 0%)
#   adding: a/im014888.png (stored 0%)
#   adding: a/im018798.png (stored 0%)
#   adding: a/im014121.png (stored 0%)
#   adding: a/im014391.png (stored 0%)
#   adding: a/im019673.png (stored 0%)
#   adding: a/im015710.png (stored 0%)
#   adding: a/im018226.png (stored 0%)
#   adding: a/im012378.png (stored 0%)
#   adding: a/im011834.png (stored 0%)
#   adding: a/im014631.png (stored 0%)
#   adding: a/im018713.png (stored 0%)
#   adding: a/im013404.png (stored 0%)
#   adding: a/im011196.png (stored 0%)
#   adding: a/im019132.png (stored 0%)
#   adding: a/im017960.png (stored 0%)
#   adding: a/im010685.png (stored 0%)
#   adding: a/im017444.png (stored 0%)
#   adding: a/im015611.png (stored 0%)
#   adding: a/im017640.png (stored 0%)
#   adding: a/im012828.png (stored 0%)
#   adding: a/im018307.png (stored 0%)
#   adding: a/im014432.png (stored 0%)
#   adding: a/im011180.png (stored 0%)
#   adding: a/im012238.png (stored 0%)
#   adding: a/im017266.png (stored 0%)
#   adding: a/im013506.png (stored 0%)
#   adding: a/im014847.png (stored 0%)
#   adding: a/im019363.png (stored 0%)
#   adding: a/im016264.png (stored 0%)
#   adding: a/im010452.png (stored 0%)
#   adding: a/im018818.png (stored 0%)
#   adding: a/im012213.png (stored 0%)
#   adding: a/im019866.png (stored 0%)
#   adding: a/im013765.png (stored 0%)
#   adding: a/im013814.png (stored 0%)
#   adding: a/im017176.png (stored 0%)
#   adding: a/im012524.png (stored 0%)
#   adding: a/im010368.png (stored 0%)
#   adding: a/im014179.png (stored 0%)
#   adding: a/im017690.png (stored 0%)
#   adding: a/im010257.png (stored 0%)
#   adding: a/im013952.png (stored 0%)
#   adding: a/im018286.png (stored 0%)
#   adding: a/im015177.png (stored 0%)
#   adding: a/im011724.png (stored 0%)
#   adding: a/im017589.png (stored 0%)
#   adding: a/im010535.png (stored 0%)
#   adding: a/im015490.png (stored 0%)
#   adding: a/im019539.png (stored 0%)
#   adding: a/im014606.png (stored 0%)
#   adding: a/im014460.png (stored 0%)
#   adding: a/im012056.png (stored 0%)
#   adding: a/im010849.png (stored 0%)
#   adding: a/im013514.png (stored 0%)
#   adding: a/im011358.png (stored 0%)
#   adding: a/im015614.png (stored 0%)
#   adding: a/im017534.png (stored 0%)
#   adding: a/im014110.png (stored 0%)
#   adding: a/im015616.png (stored 0%)
#   adding: a/im015741.png (stored 0%)
#   adding: a/im014160.png (stored 0%)
#   adding: a/im011201.png (stored 0%)
#   adding: a/im017485.png (stored 0%)
#   adding: a/im018064.png (stored 0%)
#   adding: a/im010650.png (stored 0%)
#   adding: a/im013663.png (stored 0%)
#   adding: a/im012443.png (stored 0%)
#   adding: a/im018926.png (stored 0%)
#   adding: a/im017689.png (stored 0%)
#   adding: a/im014796.png (stored 0%)
#   adding: a/im010982.png (stored 0%)
#   adding: a/im014287.png (stored 0%)
#   adding: a/im015776.png (stored 0%)
#   adding: a/im011007.png (stored 0%)
#   adding: a/im011660.png (stored 0%)
#   adding: a/im019289.png (stored 0%)
#   adding: a/im018200.png (stored 0%)
#   adding: a/im010668.png (stored 0%)
#   adding: a/im015277.png (stored 0%)
#   adding: a/im015278.png (stored 0%)
#   adding: a/im011943.png (stored 0%)
#   adding: a/im016210.png (stored 0%)
#   adding: a/im013701.png (stored 0%)
#   adding: a/im013931.png (stored 0%)
#   adding: a/im011372.png (stored 0%)
#   adding: a/im012103.png (stored 0%)
#   adding: a/im015128.png (stored 0%)
#   adding: a/im011595.png (stored 0%)
#   adding: a/im010964.png (stored 0%)
#   adding: a/im016956.png (stored 0%)
#   adding: a/im010525.png (stored 0%)
#   adding: a/im017486.png (stored 0%)
#   adding: a/im018526.png (stored 0%)
#   adding: a/im011023.png (stored 0%)
#   adding: a/im012973.png (stored 0%)
#   adding: a/im013855.png (stored 0%)
#   adding: a/im014763.png (stored 0%)
#   adding: a/im010461.png (stored 0%)
#   adding: a/im018981.png (stored 0%)
#   adding: a/im017075.png (stored 0%)
#   adding: a/im010542.png (stored 0%)
#   adding: a/im016399.png (stored 0%)
#   adding: a/im015819.png (stored 0%)
#   adding: a/im016361.png (stored 0%)
#   adding: a/im012984.png (stored 0%)
#   adding: a/im015286.png (stored 0%)
#   adding: a/im011886.png (stored 0%)
#   adding: a/im016656.png (stored 0%)
#   adding: a/im015817.png (stored 0%)
#   adding: a/im011293.png (stored 0%)
#   adding: a/im019630.png (stored 0%)
#   adding: a/im012856.png (stored 0%)
#   adding: a/im010194.png (stored 0%)
#   adding: a/im013844.png (stored 0%)
#   adding: a/im015744.png (stored 0%)
#   adding: a/im011873.png (stored 0%)
#   adding: a/im015527.png (stored 0%)
#   adding: a/im017038.png (stored 0%)
#   adding: a/im016957.png (stored 0%)
#   adding: a/im014828.png (stored 0%)
#   adding: a/im013970.png (stored 0%)
#   adding: a/im017106.png (stored 0%)
#   adding: a/im011753.png (stored 0%)
#   adding: a/im011869.png (stored 0%)
#   adding: a/im017340.png (stored 0%)
#   adding: a/im011204.png (stored 0%)
#   adding: a/im018726.png (stored 0%)
#   adding: a/im012408.png (stored 0%)
#   adding: a/im018763.png (stored 0%)
#   adding: a/im012009.png (stored 0%)
#   adding: a/im016370.png (stored 0%)
#   adding: a/im014966.png (stored 0%)
#   adding: a/im010710.png (stored 0%)
#   adding: a/im012744.png (stored 0%)
#   adding: a/im010312.png (stored 0%)
#   adding: a/im017203.png (stored 0%)
#   adding: a/im010901.png (stored 0%)
#   adding: a/im011915.png (stored 0%)
#   adding: a/im012286.png (stored 0%)
#   adding: a/im014428.png (stored 0%)
#   adding: a/im014288.png (stored 0%)
#   adding: a/im014809.png (stored 0%)
#   adding: a/im014375.png (stored 0%)
#   adding: a/im016143.png (stored 0%)
#   adding: a/im015377.png (stored 0%)
#   adding: a/im014954.png (stored 0%)
#   adding: a/im017105.png (stored 0%)
#   adding: a/im012539.png (stored 0%)
#   adding: a/im017204.png (stored 0%)
#   adding: a/im013243.png (stored 0%)
#   adding: a/im019143.png (stored 0%)
#   adding: a/im012119.png (stored 0%)
#   adding: a/im017921.png (stored 0%)
#   adding: a/im014799.png (stored 0%)
#   adding: a/im017148.png (stored 0%)
#   adding: a/im015416.png (stored 0%)
#   adding: a/im019225.png (stored 0%)
#   adding: a/im018834.png (stored 0%)
#   adding: a/im012350.png (stored 0%)
#   adding: a/im011137.png (stored 0%)
#   adding: a/im012783.png (stored 0%)
#   adding: a/im013799.png (stored 0%)
#   adding: a/im016869.png (stored 0%)
#   adding: a/im014039.png (stored 0%)
#   adding: a/im018699.png (stored 0%)
#   adding: a/im011164.png (stored 0%)
#   adding: a/im013747.png (stored 0%)
#   adding: a/im018987.png (stored 0%)
#   adding: a/im017437.png (stored 0%)
#   adding: a/im013410.png (stored 0%)
#   adding: a/im014380.png (stored 0%)
#   adding: a/im019341.png (stored 0%)
#   adding: a/im017533.png (stored 0%)
#   adding: a/im017263.png (stored 0%)
#   adding: a/im011012.png (stored 0%)
#   adding: a/im015287.png (stored 0%)
#   adding: a/im012969.png (stored 0%)
#   adding: a/im011214.png (stored 0%)
#   adding: a/im014063.png (stored 0%)
#   adding: a/im013199.png (stored 0%)
#   adding: a/im012246.png (stored 0%)
#   adding: a/im011155.png (stored 0%)
#   adding: a/im014072.png (stored 0%)
#   adding: a/im010561.png (stored 0%)
#   adding: a/im010255.png (stored 0%)
#   adding: a/im019101.png (stored 0%)
#   adding: a/im012870.png (stored 0%)
#   adding: a/im014328.png (stored 0%)
#   adding: a/im016769.png (stored 0%)
#   adding: a/im014520.png (stored 0%)
#   adding: a/im010232.png (stored 0%)
#   adding: a/im018913.png (stored 0%)
#   adding: a/im010811.png (stored 0%)
#   adding: a/im012549.png (stored 0%)
#   adding: a/im010517.png (stored 0%)
#   adding: a/im012193.png (stored 0%)
#   adding: a/im011193.png (stored 0%)
#   adding: a/im017499.png (stored 0%)
#   adding: a/im018354.png (stored 0%)
#   adding: a/im018052.png (stored 0%)
#   adding: a/im013695.png (stored 0%)
#   adding: a/im015699.png (stored 0%)
#   adding: a/im019625.png (stored 0%)
#   adding: a/im011603.png (stored 0%)
#   adding: a/im012448.png (stored 0%)
#   adding: a/im013363.png (stored 0%)
#   adding: a/im017614.png (stored 0%)
#   adding: a/im016620.png (stored 0%)
#   adding: a/im015304.png (stored 0%)
#   adding: a/im015237.png (stored 0%)
#   adding: a/im016190.png (stored 0%)
#   adding: a/im010430.png (stored 0%)
#   adding: a/im016452.png (stored 0%)
#   adding: a/im010332.png (stored 0%)
#   adding: a/im015663.png (stored 0%)
#   adding: a/im010015.png (stored 0%)
#   adding: a/im013014.png (stored 0%)
#   adding: a/im017547.png (stored 0%)
#   adding: a/im018552.png (stored 0%)
#   adding: a/im016770.png (stored 0%)
#   adding: a/im016365.png (stored 0%)
#   adding: a/im012180.png (stored 0%)
#   adding: a/im010451.png (stored 0%)
#   adding: a/im010436.png (stored 0%)
#   adding: a/im019485.png (stored 0%)
#   adding: a/im018902.png (stored 0%)
#   adding: a/im013627.png (stored 0%)
#   adding: a/im015249.png (stored 0%)
#   adding: a/im014612.png (stored 0%)
#   adding: a/im017327.png (stored 0%)
#   adding: a/im013535.png (stored 0%)
#   adding: a/im019985.png (stored 0%)
#   adding: a/im010070.png (stored 0%)
#   adding: a/im014830.png (stored 0%)
#   adding: a/im015351.png (stored 0%)
#   adding: a/im013858.png (stored 0%)
#   adding: a/im011366.png (stored 0%)
#   adding: a/im013511.png (stored 0%)
#   adding: a/im017563.png (stored 0%)
#   adding: a/im010500.png (stored 0%)
#   adding: a/im017516.png (stored 0%)
#   adding: a/im013991.png (stored 0%)
#   adding: a/im011179.png (stored 0%)
#   adding: a/im017102.png (stored 0%)
#   adding: a/im017618.png (stored 0%)
#   adding: a/im015431.png (stored 0%)
#   adding: a/im019633.png (stored 0%)
#   adding: a/im013255.png (stored 0%)
#   adding: a/im018481.png (stored 0%)
#   adding: a/im015703.png (stored 0%)
#   adding: a/im011657.png (stored 0%)
#   adding: a/im013786.png (stored 0%)
#   adding: a/im012734.png (stored 0%)
#   adding: a/im014525.png (stored 0%)
#   adding: a/im016616.png (stored 0%)
#   adding: a/im014078.png (stored 0%)
#   adding: a/im014823.png (stored 0%)
#   adding: a/im014343.png (stored 0%)
#   adding: a/im016996.png (stored 0%)
#   adding: a/im010083.png (stored 0%)
#   adding: a/im016800.png (stored 0%)
#   adding: a/im019647.png (stored 0%)
#   adding: a/im019893.png (stored 0%)
#   adding: a/im010328.png (stored 0%)
#   adding: a/im015321.png (stored 0%)
#   adding: a/im017701.png (stored 0%)
#   adding: a/im010803.png (stored 0%)
#   adding: a/im019279.png (stored 0%)
#   adding: a/im016680.png (stored 0%)
#   adding: a/im018782.png (stored 0%)
#   adding: a/im013713.png (stored 0%)
#   adding: a/im014603.png (stored 0%)
#   adding: a/im011492.png (stored 0%)
#   adding: a/im010290.png (stored 0%)
#   adding: a/im013380.png (stored 0%)
#   adding: a/im010943.png (stored 0%)
#   adding: a/im013118.png (stored 0%)
#   adding: a/im019458.png (stored 0%)
#   adding: a/im016260.png (stored 0%)
#   adding: a/im013066.png (stored 0%)
#   adding: a/im015135.png (stored 0%)

# %%
checkpoint_dir = ''
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)
#checkpoint.save(checkpoint_prefix+f"Epoch:{epoch_total}_{time.time()}")

# %%
'''tensor_array_np=generated_samples.numpy()
tensor_single=tf.convert_to_tensor(tensor_array_np[0:10000])
(tensor_single.shape)
prob=discriminator(tensor_single)
print(prob.numpy().mean())'''
size_train_test=4000
tensor_single=tf.convert_to_tensor(train_images[0:size_train_test])
prob=discriminator(tensor_single)
#print(prob.numpy().mean())
labeled_prob_train=np.hstack((prob.numpy(),np.ones((size_train_test,1))))

tensor_single=tf.convert_to_tensor(test_images[0:size_train_test])
prob=discriminator(tensor_single)
#print(prob.numpy().mean())
labeled_prob_test=np.hstack((prob.numpy(),-1*np.ones((size_train_test,1))))

labeled_probs = np.vstack((labeled_prob_train,labeled_prob_test))

# %%
fig,ax = plt.subplots()
  #"Can we determine membership inference from the output of the discriminator?"
ax.set_title(f"likelihoods with {epoch_total} epochs and {15000} images in the training set")


plt.hist(labeled_prob_train[:,0],color="tab:blue")

plt.hist(labeled_prob_test[:,0],color="tab:orange")

colors = {'training dataset':'tab:blue', 'test dataset':'tab:orange'}
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels)
plt.savefig(f"csvs/likelihoods_epoch{epoch_total}_size{15000}.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-274-a2a480f4f52e> in <cell line: 14>()
#      12 handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
#      13 plt.legend(handles, labels)
# ---> 14 plt.savefig(f"csvs/likelihoods_epoch{epoch_total}_size{15000}.png")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3341                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3342
# -> 3343             self.canvas.print_figure(fname, **kwargs)
#    3344
#    3345     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     456         """
#     457         FigureCanvasAgg.draw(self)
# --> 458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687         pil_kwargs.setdefault("format", format)
#    1688         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689         image.save(fname, **pil_kwargs)
#    1690
#    1691
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2426                 fp = builtins.open(filename, "r+b")
#    2427             else:
# -> 2428                 fp = builtins.open(filename, "w+b")
#    2429
#    2430         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'csvs/likelihoods_epoch1200_size15000.png'

# %%
asd=labeled_probs[labeled_probs[:, 0].argsort()][::-1]
asd[asd[:,1]==-1,1]=0
top_k=[5,10,20,50,100,200,500,1000,1200]
tp_out_of_top_k=list()
for count,k in enumerate(top_k):
  tp_out_of_top_k.append(asd[0:k,1].sum())
csv_topk=np.vstack((np.array(top_k,dtype=np.int32),np.array(tp_out_of_top_k,dtype=np.int32)))
np.savetxt(f"csvs/csv{epoch_total}.csv",csv_topk,delimiter=',')
csv_topk
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-275-dd328b7bb2c0> in <cell line: 8>()
#       6   tp_out_of_top_k.append(asd[0:k,1].sum())
#       7 csv_topk=np.vstack((np.array(top_k,dtype=np.int32),np.array(tp_out_of_top_k,dtype=np.int32)))
# ----> 8 np.savetxt(f"csvs/csv{epoch_total}.csv",csv_topk,delimiter=',')
#       9 csv_topk
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in savetxt(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1521     if _is_string_like(fname):
#    1522         # datasource doesn't support creating a new file ...
# -> 1523         open(fname, 'wt').close()
#    1524         fh = np.lib._datasource.open(fname, 'wt', encoding=encoding)
#    1525         own_fh = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'csvs/csv1200.csv'

# %%
def plot_membership(tp,fp,tn,fn,title):
  fig,ax = plt.subplots()
  #"Can we determine membership inference from the output of the discriminator?"
  ax.set_title(title)
  colors = {'training dataset':'red', 'test dataset':'blue'}
  bar = plt.bar(np.array(["true positives","false positives","true negatives","false negatives"]),[int(tp),int(fp),int(tn),int(fn)],color=["red","blue","blue","red"])

  labels = list(colors.keys())
  handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
  plt.legend(handles, labels)

  #plt.bar(("tp","tn","fp","fn"),(tp,tn,fp,fn))

# %%
#"Can we determine membership inference from the output of the discriminator?"
cutoff=0.48
#labeled_probs[::-1].sort(axis=0)
tp=((labeled_probs[:,0]>cutoff) & (labeled_probs[:,1]>0)).sum()
tn=((labeled_probs[:,0]<=cutoff) & (labeled_probs[:,1]<0)).sum()
fp=((labeled_probs[:,0]>cutoff) & (labeled_probs[:,1]<0)).sum()
fn=((labeled_probs[:,0]<=cutoff) & (labeled_probs[:,1]>0)).sum()
plot_membership(tp,fp,tn,fn,f"membership inference with output of discriminator: cutoff at {cutoff}")
